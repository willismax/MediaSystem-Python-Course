# %% [markdown]
# # 媒體倫理：發布前檢查與 AI 揭露
#
# 分層學習教材。先完成基礎練習，再選擇標準實作或延伸挑戰。

# %% [markdown]
# ## Goal
#
# 在發布前辨識素材授權、個資、肖像與生成式 AI 揭露需求。

# %% [markdown]
# ## Setup
#
# 此單元不需要安裝套件；直接填寫下列欄位並存下自己的專題紀錄。

# %% [markdown]
# ## Steps

# %% [markdown]
# ### 1. 素材紀錄
#
# 基礎必做：完成一筆素材來源紀錄。

# %%
asset = {
    '素材名稱': '', '來源與作者': '', '授權': '',
    '使用或修改方式': '', '人物或個資處理': '',
    'AI或第三方API揭露': ''
}
asset

# %% [markdown]
# ### 2. 發布前檢查
#
# 標準實作：逐項確認；有任何一項不確定就先不要公開。

# %%
checklist = ['來源與授權清楚', '無未同意的人臉或個資', 'AI/API 使用已揭露', '沒有在版本庫放入金鑰']
for item in checklist: print('□', item)

# %% [markdown]
# ## Checks
#
# 能否說出一個需要標示的情境，以及一個應先取得同意或改用素材的情境？

# %% [markdown]
# ## Next Steps
#
# 進階挑戰：為期末作品訂出由誰、何時完成發布前審核的流程。
