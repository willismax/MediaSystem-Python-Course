# %% [markdown]
# <a href="https://colab.research.google.com/github/willismax/MediaSystem-Python-Course/blob/main/01.Intro-Python/%E4%BE%86%E7%95%AB%E5%9C%96%E5%A5%BD%E5%97%8E_%E8%B3%87%E6%96%99%E8%A6%96%E8%A6%BA%E5%8C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 資料視覺化

# %% [markdown]
# ## 選用合適的圖表呈現

# %% [markdown]
# ![](https://i.imgur.com/zSCAxBi.png)

# %% [markdown]
# ## Matplotlib可視化
# ![](https://matplotlib.org/stable/_static/logo2_compressed.svg)

# %% [markdown]
# - https://matplotlib.org/stable/index.html
#
# - Matplotlib 是一個強大的 Python 繪圖庫，用於創建廣泛的靜態、動態和交互式圖形。它是基於 NumPy 的多平台數據可視化工具，與 SciPy 和其他科學計算工具包配合使用效果最佳。以下是 Matplotlib 的一些重要特點和應用場景：
#
# - 主要特點：
#   - 多平台和多輸出格式支持： Matplotlib 支持數十種後端和輸出類型，這使得它非常靈活，能夠在多種操作系統上運行，並輸出各種所需格式的圖形，包括但不限於 PNG, PDF, SVG, EPS，甚至是互動式圖形。
#   - 豐富的繪圖功能： 使用 Matplotlib，用戶可以繪製各種圖形，如折線圖、柱狀圖、散點圖、餅圖等，並能對圖形進行高度自定義，如調整顏色、標籤、圖例等。
#   - 與科學計算生態系的整合： Matplotlib 是科學計算和數據分析生態系統中的基礎組件，與 NumPy、SciPy、pandas 等庫緊密整合，是數據分析和科學研究的重要工具。
# - 應用場景：
#   - 科學研究： 如哈伯太空望遠鏡團隊使用 Matplotlib 來分析天文數據，展示研究成果。
#   - 數據分析： 在商業和學術領域廣泛用於數據探索和呈現結果，尤其適用於需要細致呈現數據圖表的情境。
#   - 教育和培訓： 在教育領域，Matplotlib 常被用於教授數據可視化的基本概念和技巧。
# - 競爭與創新：
#   - 與其他工具的比較： 雖然如 R 語言的 ggplot2、基於網頁的 D3.js 和無需編程的 Tableau/PowerBI 提供了更現代化的視覺效果或更用戶友好的操作界面，Matplotlib 在某些方面可能看起來較為傳統。
#   - 創新與社群支持： 儘管面臨競爭，Matplotlib 的龐大使用者社群仍然持續推動其發展。新興的套件，如 Seaborn（其設計理念類似於 ggplot2），增強了 Matplotlib 的繪圖功能，提供了更豐富的視覺效果和更好的用戶體驗。
#
# Matplotlib 繼續在其強大的社群支持和持續的開發進程中扮演著重要角色，為用戶提供可靠且功能豐富的數據可視化工具。

# %% [markdown]
# ### 起手式

# %% [markdown]
# ## 使用設定
# - 安裝套件、載入、在筆記本顯示(inline 模式)、儲存檔案

# %%
# 安裝Matplotlib，Colab預設已安裝
# !pip install matplotlib > log.txt

# %%
# 在notebook顯示，Colab預設即是inline
# %matplotlib inline

# 載入套件
import matplotlib.pyplot as plt

# %% [markdown]
# 範例一

# %%
# %%file demo_01.py
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, np.pi*5, 100)
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# 圖片可以使用`fig.savefig()`存為圖檔，可以用`fig.canvas.get_supported_filetypes()`查看支援的圖片種類

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# 範例二

# %%
# 範例二
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
x = np.linspace(0, np.pi*4, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
fig.savefig('myfig01.png') # 以.png輸出
fig.savefig('myfig01.pdf') # 以.pdf輸出

# %% [markdown]
# - 以`plt.subplots`畫出子圖集，並且以陣列的方式分別繪製子圖

# %%
# 先建立圖表的格子
# ax是個2軸物件的陣列
fig, ax = plt.subplots(2)

# 在適當的物件上呼叫plot()
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# - 2*2子圖集

# %%
# ax是個2軸物件的陣列
fig, ax = plt.subplots(2,2)

# 在適當的物件上呼叫plot()
ax[0,0].plot(x, np.sin(x))
ax[1,0].plot(x, np.cos(x))
ax[0,1].plot(x, np.cos(x))

# %% [markdown]
# - 所有的Matplotlib圖表，都從建立一個figure和axes開始
#   - `plt.figure`:畫布(容器)
#   - `plt.axes`:邊界、刻度、標籤

# %% [markdown]
# ### 圖樣樣式

# %% [markdown]
# - style清冊 https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
import matplotlib.pyplot as plt

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')

fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# ### 調整軸的尺度

# %% [markdown]
# - 以`plt.xlim()`、`plt.ylim()`調整軸範圍

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, np.pi*4, 100)
plt.plot(x, np.sin(x))

plt.xlim(-5, 20)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# - 以`plt.axis([xmin, xmax, ymin, ymax])`調整範圍

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (np.float64(-1.0), np.float64(11.0), np.float64(-1.5), np.float64(1.5))

# %% [markdown]
# - `plt.axis('tight')`調整為緊湊間距
# - `plt.axis('equal')`調整為讓在螢幕上x單位等於y單位

# %%
# x = np.linspace(0, np.pi*4, 100)
plt.plot(x, np.sin(x))

plt.axis('tight')
# plt.axis('equal')
# Out:
# (np.float64(0.0),
#  np.float64(12.566370614359172),
#  np.float64(-0.9998741276738751),
#  np.float64(0.9998741276738751))

# %% [markdown]
# ### 設定標籤（含中文顯示）

# %% [markdown]
# - 以`plt.title()`設定標題
# - 以`plt.xlabel()`設定x軸文字
# - 以`plt.ylabel()`設定y軸文字

# %% [markdown]
# ## matplotlib圖形顯示中文靠這行
# 預設無法顯示中文，以下為解法
# - https://ithelp.ithome.com.tw/articles/10234373

# %%
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib

# 改style要在改font之前
# plt.style.use('seaborn')

matplotlib.font_manager.fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
matplotlib.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2025-06-30 22:20:33--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.196.102, 74.125.196.138, 74.125.196.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.196.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2025-06-30 22:20:33--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.107.132, 2607:f8b0:400c:c32::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.107.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...

# %%
# @title
#@title: 完整版
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# 確認並安裝所需的 Matplotlib 模組
try:
    import matplotlib
    import matplotlib.font_manager as font_manager
except ImportError:
    install('matplotlib')
    import matplotlib
    import matplotlib.font_manager as font_manager

# 下載並添加字體
try:
    # 使用 requests 下載字體檔案
    import requests
    print("Downloading font...")
    url = 'https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download'
    r = requests.get(url)
    with open('TaipeiSansTCBeta-Regular.ttf', 'wb') as f:
        f.write(r.content)

    # 添加字體至 Matplotlib
    font_manager.fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
    matplotlib.rc('font', family='Taipei Sans TC Beta')
    print("Font successfully added.")

    # 檢查字體有無正確被添加
    fonts_list = [f.name for f in font_manager.fontManager.ttflist]
    if "Taipei Sans TC Beta" in fonts_list:
        print("Taipei Sans TC Beta font is successfully added to the font list.")
    else:
        print("Taipei Sans TC Beta font is not found in the font list.")

except Exception as e:
    print(f"Failed to download or add the font. Error: {e}")
# Out:
# ...
# Font successfully added.
# Taipei Sans TC Beta font is successfully added to the font list.

# %%
# @title
# 本Cell腳本會失敗，原因是基於matplotlib對於外部腳本執行的安全性
# !wget -O setup_matplotlib_chinese_font.py https://gist.githubusercontent.com/willismax/5cfac81687dd08c5ff404c85f7cea61a/raw/a9aa5dd56fe3b4bdd8dedb86e90bc72b7a5dee91/setup_matplotlib_chinese_font.py
# !python setup_matplotlib_chinese_font.py

# %%
import matplotlib

[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# "Taipei Sans TC Beta" in [f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'DejaVu Sans Display',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'cmsy10',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'STIXSizeFiveSym',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'cmex10',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'cmtt10',
#  'cmmi10',
#  'STIXSizeTwoSym',
#  'cmr10',
#  'STIXNonUnicode',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Humor Sans',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, np.pi*4, 100)

plt.plot(x, np.sin(x))
plt.title("A Sine Curve圖形")
plt.xlabel("x軸")
plt.ylabel("sin($x$)");#Letex

# %% [markdown]
# - 充滿血淚的中文Colab顯示解法
#   1. 下載正體中文字型置於colab指定路徑，但路徑會隨版本變更。
#   2. 每段輸出時分別指定字型fontproperties屬性，如:
#
#     - `plt.title("自訂標題",fontproperties=myfont)`
#     - `plt.ylabel("自訂y軸",fontproperties=myfont)`
#     - `plt.xlabel("自訂x軸",fontproperties=myfont)`
#
# - 參閱[github](https://github.com/willismax/matplotlib_show_chinese_in_colab/blob/master/matplotlib_show_chinese_in_colab.ipynb)、[Day 11 : Google Colab 實用奧步篇 ( 連結硬碟、繪圖中文顯示問題 )](https://ithelp.ithome.com.tw/articles/10234373)

# %% [markdown]
# - plt函式跟ax函式原則可以直接轉換，常遇到的例外如下
#  - `plt.xlabel()` → `ax.set_xlabel()`
#  - `plt.ylabel()` → `ax.set_ylabel()`
#  - `plt.xlim()` → `ax.set_xlim()`
#  - `plt.ylim()` → `ax.set_ylim()`
#  - `plt.title()` → `ax.set_title()`

# %% [markdown]
# #### 設定圖例

# %% [markdown]
# - 以`plt.legeng()`將自動建立具有標籤與圖示的圖例

# %%
import matplotlib.pyplot as plt

plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '.b', label='Sine') #linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
ax.plot(x, np.cos(x), '-.r', label='Cosine') #查閱ax.plpt有更多參數
ax.axis('equal')


leg = ax.legend() #預設自動找空白處

# %% [markdown]
# - 以`loc`屬性指定位置、`frameon`屬性設定是否有框線

# %%
ax.legend(loc='upper left', frameon=False)
fig

# %% [markdown]
# - 圓角、陰影、框透明度、厚度

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# #### 箭頭與註解

# %%
# %matplotlib inline
plt.style.use('classic')

fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate(
    '區域最大值local maximum',
    xy=(6.28, 1),
    xytext=(10, 4),
    arrowprops=dict(
        facecolor='black',
        shrink=0.05),
    fontproperties='Taipei Sans TC Beta'
    )

ax.annotate(
    'local minimum',
    xy=(5 * np.pi, -1),
    xytext=(2, -6),
    arrowprops=dict(
        arrowstyle="->",
        connectionstyle="angle3,angleA=0,angleB=-90"
        )
    )
# Out:
# Text(2, -6, 'local minimum')

# %% [markdown]
# ### 簡單線條圖(折線圖)Line Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
import numpy as np

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
# 一張圖顯示兩條線：一起寫再plt.show()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(x+2, np.cos(x))

# %% [markdown]
# - 不同顏色的定義方法

# %%
#plt.plot(x,y , '--b')

plt.plot(x, np.sin(x-0), color='blue')
plt.plot(x, np.sin(x-1), color='g')  # 使用顏色編碼rgb cmyk
plt.plot(x, np.sin(x-2), color='0.75')  # 0到1的灰階
plt.plot(x, np.sin(x-3), color='#FFDD44')  # 16進位編碼(RRGGBB from 00 to FF)
plt.plot(x, np.sin(x-4), color=(1.0,0.2,0.3))  # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x-5), color='chartreuse')  # 所有HTML支援的顏色名稱

# %% [markdown]
# - 不同線條樣式定義方法

# %%
plt.plot(x, x+0, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+2, linestyle='dashdot')
plt.plot(x, x+3, linestyle='dotted');

# 簡易表達方式:
plt.plot(x, x+5, linestyle='-')  # solid
plt.plot(x, x+6, linestyle='--') # dashed
plt.plot(x, x+7, linestyle='-.') # dashdot
plt.plot(x, x+8, linestyle=':')  # dotted

# %% [markdown]
# - 顏色及線條樣式簡易寫法

# %%
plt.plot(x, x+0, '-g')
plt.plot(x, x+1, '--c')
plt.plot(x, x+2, '-.k')
plt.plot(x, x+3, ':r')

# %% [markdown]
# ## 散佈圖Scatter Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
import numpy as np

# %% [markdown]
# #### 方案1:沿用plt.plot()

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')
plt.plot(x, y+1, 'om')

# %% [markdown]
# #### 方案2:使用plt.scatter()

# %%
plt.scatter(x, y, marker='o');

# %% [markdown]
# - `plt.scatter()`可以做更多的細微操作，如以下四維圖(x軸、y軸、顏色、大小)
# - 但大量運算時耗資源請改用`plt.plot()`，因為`plt.plot()`採用複製，`plt.scatter()`為逐一渲染

# %%
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar();  # 顯示顏色尺度

# %% [markdown]
# - 鳶尾花Iris資料集視覺化
#   - x、y為花萼的長度與寬度
#   - 點的大喜為花瓣的寬度
#   - 顏色為花的特定種類

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

print(features)

plt.scatter(
    features[0],
    features[1],
    alpha=0.2,
    s=100*features[3],
    c=iris.target,
    cmap='viridis')

plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
# Out:
# [[5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#   5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#   5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#   6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#   6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#   5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#   6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#   6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#   6.7 6.7 6.3 6.5 6.2 5.9]
#  [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#   3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#   3.5 3.6 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#   2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
# ...

# %% [markdown]
# ## 直方圖Histograms

# %% [markdown]
# - 直方圖histogram：以長條狀的圖表達數量的統計圖型，長條間**有**連在一起(連續資料適用)。
# - 常用來觀察資料的分布情形。

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  3.,  12.,  49., 157., 241., 256., 172.,  86.,  20.,   4.]),
#  array([-3.39710271, -2.73594487, -2.07478703, -1.41362919, -0.75247134,
#         -0.0913135 ,  0.56984434,  1.23100218,  1.89216002,  2.55331786,
#          3.2144757 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(
    data,
    bins=30,
    alpha=0.5,
    histtype='stepfilled',
    color='steelblue',
    edgecolor='none'
    )
# Out:
# (array([ 1.,  1.,  1.,  1.,  5.,  6.,  9., 19., 21., 46., 41., 70., 64.,
#         81., 96., 84., 79., 93., 71., 62., 39., 42., 23., 21.,  8.,  8.,
#          4.,  2.,  1.,  1.]),
#  array([-3.39710271, -3.17671676, -2.95633081, -2.73594487, -2.51555892,
#         -2.29517297, -2.07478703, -1.85440108, -1.63401513, -1.41362919,
#         -1.19324324, -0.97285729, -0.75247134, -0.5320854 , -0.31169945,
#         -0.0913135 ,  0.12907244,  0.34945839,  0.56984434,  0.79023029,
#          1.01061623,  1.23100218,  1.45138813,  1.67177407,  1.89216002,
#          2.11254597,  2.33293191,  2.55331786,  2.77370381,  2.99408976,
#          3.2144757 ]),
#  [<matplotlib.patches.Polygon at 0x7e81c3d68350>])

# %% [markdown]
# - `histtype='stepfilled'`, `alpha`屬性結合表示資料分布

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# ## 長條圖bar chart

# %% [markdown]
# - 以長條狀的圖表達數量的統計圖型，長條間**沒有**連在一起(非連續資料、名目資料、不同類別適用)。

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

district = (
    'Cambridge City',
    'East Cambridgeshire',
    'Fenland',
    'Huntingdonshire',
    'South Cambridgeshire')
population = (123900, 83800, 95300, 169500, 148800)
plt.bar(district, population)
# Out:
# <BarContainer object of 5 artists>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

district = ('Cambridge City', 'East Cambridgeshire', 'Fenland', 'Huntingdonshire',
            'South Cambridgeshire')
population = (123900, 83800, 95300, 169500, 148800)
error = [500, 10000, 700, 5000, 20000] #設為誤差值
plt.barh(district, population, xerr=error, align='center')
plt.yticks(fontsize=14)
plt.xlabel('Population')
plt.title('2011 population distribution')
# Out:
# Text(0.5, 1.0, '2011 population distribution')

# %% [markdown]
# ## 堆疊圖 Stack Plot

# %%
# prompt: 堆疊圖 Stack Plot

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-v0_8-white')

days = [1, 2, 3, 4, 5]
sleeping = [7, 8, 6, 11, 7]
eating = [2, 3, 4, 3, 2]
working = [7, 8, 7, 2, 2]
playing = [8, 5, 7, 8, 13]

plt.stackplot(days, sleeping, eating, working, playing, colors=['moccasin', 'navajowhite', 'peachpuff', 'papayawhip'])
plt.xlabel('Days')
plt.ylabel('Hours')
plt.title('Stack Plot')
plt.legend(['Sleeping', 'Eating', 'Working', 'Playing'])

# %% [markdown]
# ## 圓餅圖Pie charts

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

district = ('Cambridge City', 'East Cambridgeshire', 'Fenland', 'Huntingdonshire', 'South Cambridgeshire')
population = (123900, 83800, 95300, 169500, 148800)

colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']

# "explode" 向外擴展
explode = (0.2, 0.0, 0, 0, 0)

# Produce pie chart. The slices will be ordered and plotted counter-clockwise.
plt.pie(
    population,
    explode=explode,
    labels=district,
    colors=colors,
    autopct='%1.1f%%',
    shadow=True,
    startangle=90)

plt.title("2011 population distribution")
# Out:
# Text(0.5, 1.0, '2011 population distribution')

# %% [markdown]
# ## 箱型圖Box Plot

# %% [markdown]
# - 可以顯示最高、最低、四分位數(含中位數)，通常會先分類別再顯示數值，以作為比較之用。

# %%
# prompt: box plot

import matplotlib.pyplot as plt
import numpy as np

# Create a boxplot of the iris dataset
iris = load_iris()
plt.boxplot(iris.data)

# Add labels and title
plt.xlabel('Sepal length', fontsize=16)
plt.ylabel('Sepal width', fontsize=16)
plt.title('Boxplot of Iris Dataset', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# ## 小提琴圖

# %% [markdown]
# - 除了顯示最大、最小值及中位數，也顯示出資料的分布情形，能展示出更多資訊。

# %%
# prompt: violinplot

import matplotlib.pyplot as plt
# Create a violinplot of the iris dataset
iris = load_iris()
plt.violinplot(iris.data)

# Add labels and title
plt.xlabel('Sepal length', fontsize=16)
plt.ylabel('Sepal width', fontsize=16)
plt.title('Violinplot of Iris Dataset', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# ## 3D圖

# %%
# prompt: matplotlib 3d plot

from mpl_toolkits.mplot3d import Axes3D  # 導入3D繪圖工具包
import matplotlib.pyplot as plt
import numpy as np

# 1. 創建3D圖形對象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 2. 生成數據
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# 3. 繪製曲面圖
ax.plot_surface(X, Y, Z, cmap='rainbow')

# 4. 設置圖形標題和軸標籤
ax.set_title('3D Surface Plot')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# 5. 顯示圖形
plt.show()

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %% [markdown]
# ## 多重子圖表

# %% [markdown]
# - `plt.axes()`可建立畫布，子畫布可用list標示位置，所代表的位置為``[left, bottom, width, height]``

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')
import numpy as np

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %% [markdown]
# - 建立垂直堆疊的axes

# %%
fig = plt.figure()
ax1 = fig.add_axes(
          [0.1, 0.5, 0.8, 0.4],
          xticklabels=[],
          ylim=(-1.2, 1.2)
          )
ax2 = fig.add_axes(
          [0.1, 0.1, 0.8, 0.4],
          ylim=(-1.2, 1.2)
          )

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %% [markdown]
# #### plt.subplot()子圖表簡單網格系統

# %% [markdown]
# - plt.subplot(列數, 欄數, 第i圖)

# %%
for i in range(1, 7):
  plt.subplot(2, 3, i)
  plt.text(0.5, 0.5,
  str((2, 3, i)),
  fontsize=18,
  ha='center'
  )

# %% [markdown]
# - `plt.subplots_adjust()`的`hspace`和`wspace`屬性以指定寬、高間隔，以子圖的尺寸為度。

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %% [markdown]
# #### 以``plt.subplots()``一次準備好整個網格

# %%
fig, ax = plt.subplots(2, 3)

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
  for j in range(3):
    ax[i, j].text(0.5,0.5,str((i,j)), fontsize=18, ha='center')
fig

# %%
# 建立常態分佈資料
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# 使用axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(
    x,
    40,
    histtype='stepfilled',
    orientation='vertical',
    color='gray'
    )
x_hist.invert_yaxis()

y_hist.hist(
    y,
    40,
    histtype='stepfilled',
    orientation='horizontal',
    color='gray')

y_hist.invert_xaxis()

# %% [markdown]
# # 以Seaborn視覺化

# %% [markdown]
# - Seaborn可作為matplotlib的改良版，輕易地進行介接，並可與pandas更好結合

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')

rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
import seaborn as sns
sns.set()

# %%
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], alpha=0.5)

# %%
with sns.axes_style('white'):
  sns.jointplot(x="x", y="y", data=data, kind='kde')

# %%
with sns.axes_style('white'):
  sns.jointplot(x="x", y="y", data=data, kind='hex')

# %%
# prompt: sns replot with tips data
import seaborn as sns

sns.set()

tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="day", col="time", row="sex" ,data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="size", size="size", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(y="total_bill", x="tip", hue="sex", style="sex", data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips) #大資料時不建議用
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", split=True, data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxenplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## 延伸閱讀

# %% [markdown]
# - [ ODEC Quarterly GDP Data - GitHub](https://nbviewer.jupyter.org/github/gloveyen/Data-Visualization/blob/master/ODEC%20Quarterly%20GDP%20Data.ipynb?fbclid=IwAR3ZpVWCBTSR6pspxH9KJyfLI7qwTgi8OU5bc0hjBovb__Mc3HWgQ9iRpOM)
# - [5 Quick and Easy Data Visualizations in Python with Code - towardsdatascience.com](https://towardsdatascience.com/5-quick-and-easy-data-visualizations-in-python-with-code-a2284bae952f)
# - [[資料分析&機器學習] 第2.5講：資料視覺化(Matplotlib, Seaborn, Plotly)](https://medium.com/jameslearningnote/%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90-%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92-%E7%AC%AC2-5%E8%AC%9B-%E8%B3%87%E6%96%99%E8%A6%96%E8%A6%BA%E5%8C%96-matplotlib-seaborn-plotly-75cd353d6d3f)

# %% [markdown]
# - [Python資料科學學習手冊(中)](https://www.books.com.tw/exep/assp.php/peterli/products/0010774364?utm_source=peterli&utm_medium=ap-books&utm_content=recommend&utm_campaign=ap-201905)、[(英github)](https://jakevdp.github.io/PythonDataScienceHandbook/)
# - [Charts in Colab - colab](https://colab.research.google.com/notebooks/charts.ipynb#scrollTo=xNzEBRkzL3B0)
# - [資料視覺化最有價值的50個圖表！掌握這些圖表基本就是大牛了！ - itread01](https://www.itread01.com/content/1546568591.html)
# - https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb
