# %% [markdown]
# <a href="https://colab.research.google.com/github/willismax/MediaSystem-Python-Course/blob/main/course-115-v2/colab/W01_MS_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install Pillow

# %%
"""我的第一支多媒體程式 — 生成一張漸層色卡"""
from PIL import Image

width, height = 800, 400
img = Image.new("RGB", (width, height))

# 逐一設定每個像素的顏色，做出由藍到橘的水平漸層
for x in range(width):
    ratio = x / width            # 0.0（最左）到 1.0（最右）
    r = int(255 * ratio)
    g = int(120 * ratio)
    b = int(255 * (1 - ratio))
    for y in range(height):
        img.putpixel((x, y), (r, g, b))

img.save("my_first_gradient.png")
print("完成！請打開 my_first_gradient.png。")
# Out:
# 完成！請打開 my_first_gradient.png。
