# %%
import datetime
from flask  import Flask, jsonify
import requests
import json
import time

# %%
def get_cinema_income():
    start_date = (datetime.datetime.now() - datetime.timedelta(80)).strftime("%Y/%m/%d") #前80日
    end_date = datetime.datetime.now().strftime("%Y/%m/%d")
    url = f'https://boxoffice.tfi.org.tw/api/export?start={str(start_date)}&end={str(end_date)}'
    res = requests.get(url)
    time.sleep(3)
    return res.json()

def save_josn_data():
    data = get_cinema_income()
    with open('./static/data.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
save_josn_data()

# %%
def load_json_data():
    try:
        with open('./static/data.json', 'r', encoding='utf-8') as f:
            data = json.load(f)
            return data
    except:
        print('load json data error')

# %%
load_json_data()
# Out:
# {'start': '2022-09-28T00:00:00',
#  'end': '2022-12-17T00:00:00',
#  'list': [{'country': '法國',
#    'name': '全面開戰',
#    'releaseDate': '2018-12-02T00:00:00',
#    'issue': '佳映娛樂國際股份有限公司',
#    'produce': 'MK2 Films',
#    'theaterCount': 3,
#    'tickets': 82,
#    'ticketChangeRate': 1.0,
#    'amounts': 19250.0,
#    'totalTickets': 906,
#    'totalAmounts': 196341.0},
#   {'country': '日本',
#    'name': '劇場版 歌之☆王子殿下♪真愛KINGDOM',
#    'releaseDate': '2019-06-14T00:00:00',
#    'issue': '曼迪傳播有限公司',
#    'produce': 'KING RECORD COMPANY LIMITED',
#    'theaterCount': 1,
#    'tickets': 0,
#    'ticketChangeRate': 1.0,
#    'amounts': 0.0,
#    'totalTickets': 10804,
#    'totalAmounts': 2819486.0},
#   {'country': '中華民國',
#    'name': '海上花',
#    'releaseDate': '1998-10-01T00:00:00',
#    'issue': '傳影互動股份有限公司',
#    'produce': '三三電影製作有限公司',
#    'theaterCount': 6,
#    'tickets': 92,
#    'ticketChangeRate': 0.6428571428571429,
#    'amounts': 21197.0,
#    'totalTickets': 2585,
#    'totalAmounts': 575642.0},
#   {'country': '中華民國',
#    'name': '奼紫嫣紅開遍',
#    'releaseDate': '2015-12-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 87,
#    'ticketChangeRate': 1.0,
#    'amounts': 20875.0,
#    'totalTickets': 87,
#    'totalAmounts': 20875.0},
#   {'country': '中華民國',
#    'name': '1918',
#    'releaseDate': '2015-12-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 44,
#    'ticketChangeRate': 1.0,
#    'amounts': 11070.0,
#    'totalTickets': 44,
#    'totalAmounts': 11070.0},
#   {'country': '中華民國',
#    'name': '東西',
#    'releaseDate': '2015-12-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 22,
#    'ticketChangeRate': 1.0,
#    'amounts': 5140.0,
#    'totalTickets': 22,
#    'totalAmounts': 5140.0},
#   {'country': '日本',
#    'name': '藍色恐懼：數位修復版',
#    'releaseDate': '2020-07-17T00:00:00',
#    'issue': '光年映畫有限公司',
#    'produce': 'MADHOUSE Inc. ',
#    'theaterCount': 6,
#    'tickets': 386,
#    'ticketChangeRate': 1.0,
#    'amounts': 100001.0,
#    'totalTickets': 39951,
#    'totalAmounts': 9472167.0},
#   {'country': '香港',
#    'name': '麥路人',
#    'releaseDate': '2020-09-17T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': '寰亞電影製作有限公司##無限動力實業有限公司##北京拉近影業有限公司##寰亞電影發行(北京）有限公司##中影寰亞音像製品有限公司##墨客行影業（北京）有限公司##雅美星有限公司##霍爾果斯泰洋川禾文化傳媒有限公司##百代環球(北京)國際資產管理有限公司##北京林夕影業有限公司##北京大美寰宇影業有限公司##星光聯盟影業無錫有限公司',
#    'theaterCount': 1,
#    'tickets': 100,
#    'ticketChangeRate': 1.0,
#    'amounts': 22000.0,
#    'totalTickets': 18103,
#    'totalAmounts': 3844706.0},
#   {'country': '南斯拉夫',
#    'name': '地下社會',
#    'releaseDate': '2015-05-15T00:00:00',
#    'issue': '前景娛樂有限公司',
#    'produce': 'TF1 INTERNATIONAL',
#    'theaterCount': 1,
#    'tickets': 17,
#    'ticketChangeRate': -0.903954802259887,
#    'amounts': 3740.0,
#    'totalTickets': 3020,
#    'totalAmounts': 669460.0},
#   {'country': '日本',
#    'name': '紫羅蘭永恆花園電影版',
#    'releaseDate': '2020-09-30T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': 'ABC Animation,INC.',
#    'theaterCount': 1,
#    'tickets': 38,
#    'ticketChangeRate': 1.0,
#    'amounts': 13170.0,
#    'totalTickets': 111103,
#    'totalAmounts': 27760099.0},
#   {'country': '中華民國',
#    'name': '削瘦的靈魂',
#    'releaseDate': '2021-03-19T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 1,
#    'tickets': 0,
#    'ticketChangeRate': -1.0,
#    'amounts': 0.0,
#    'totalTickets': 2182,
#    'totalAmounts': 490214.0},
#   {'country': '中華民國',
#    'name': '徘徊年代',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '光元體影藝有限公司',
#    'produce': '光元體影藝有限公司,傳影互動股份有限公司',
#    'theaterCount': 2,
#    'tickets': 193,
#    'ticketChangeRate': -0.9514953505906006,
#    'amounts': 46630.0,
#    'totalTickets': 3424,
#    'totalAmounts': 774800.0},
#   {'country': '中華民國',
#    'name': '綠色牢籠',
#    'releaseDate': '2021-05-14T00:00:00',
#    'issue': '木林電影有限公司',
#    'produce': '木林電影有限公司,株式会社ムーリンプロダクション',
#    'theaterCount': 1,
#    'tickets': 53,
#    'ticketChangeRate': 1.0,
#    'amounts': 14310.0,
#    'totalTickets': 1399,
#    'totalAmounts': 311782.0},
#   {'country': '秘魯',
#    'name': '亞馬遜守護者：安珀傳奇(英語版)',
#    'releaseDate': '2022-01-13T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'CINEMA MANAGEMENT GROUP,LLC',
#    'theaterCount': 1,
#    'tickets': 65,
#    'ticketChangeRate': 1.0,
#    'amounts': 14300.0,
#    'totalTickets': 165,
#    'totalAmounts': 37300.0},
#   {'country': '美國',
#    'name': '齊瓦哥醫生',
#    'releaseDate': '2022-10-05T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 16,
#    'tickets': 1376,
#    'ticketChangeRate': 1.0,
#    'amounts': 364889.0,
#    'totalTickets': 1376,
#    'totalAmounts': 364889.0},
#   {'country': '美國',
#    'name': '金甲部隊',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 2,
#    'tickets': 2,
#    'ticketChangeRate': -0.9991708126036484,
#    'amounts': 420.0,
#    'totalTickets': 2414,
#    'totalAmounts': 590773.0},
#   {'country': '日本',
#    'name': '總編的復仇',
#    'releaseDate': '2021-11-05T00:00:00',
#    'issue': '可樂藝術文創股份有限公司',
#    'produce': 'Shochiku Co.,Ltd.',
#    'theaterCount': 1,
#    'tickets': 98,
#    'ticketChangeRate': 1.0,
#    'amounts': 21560.0,
#    'totalTickets': 572,
#    'totalAmounts': 125309.0},
#   {'country': '中華民國',
#    'name': '美國女孩',
#    'releaseDate': '2021-12-03T00:00:00',
#    'issue': '水花電影股份有限公司',
#    'produce': '水花電影股份有限公司,寰亞電影製作有限公司,杰威爾音樂有限公司,G.H.Y. Culture & Media (Singapore)',
#    'theaterCount': 1,
#    'tickets': 131,
#    'ticketChangeRate': -0.7933753943217665,
#    'amounts': 28820.0,
#    'totalTickets': 82093,
#    'totalAmounts': 19255486.0},
#   {'country': '美國',
#    'name': '達賴的一生',
#    'releaseDate': '2022-07-08T00:00:00',
#    'issue': '東昊影業有限公司',
#    'produce': 'Studiocanal S.A.S',
#    'theaterCount': 2,
#    'tickets': 117,
#    'ticketChangeRate': -0.9798692360633173,
#    'amounts': 20250.0,
#    'totalTickets': 6170,
#    'totalAmounts': 1379097.0},
#   {'country': '日本',
#    'name': '刀劍神域劇場版 –Progressive- 無星夜的詠嘆調 ',
#    'releaseDate': '2021-11-12T00:00:00',
#    'issue': '木棉花國際股份有限公司',
#    'produce': 'Aniplex Inc.',
#    'theaterCount': 8,
#    'tickets': 1512,
#    'ticketChangeRate': 1.0,
#    'amounts': 372915.0,
#    'totalTickets': 132736,
#    'totalAmounts': 35103931.0},
#   {'country': '法國',
#    'name': '仰望星空的少年',
#    'releaseDate': '2021-12-03T00:00:00',
#    'issue': '海鵬影業有限公司',
#    'produce': 'TOTEM FILMS',
#    'theaterCount': 1,
#    'tickets': 53,
#    'ticketChangeRate': 1.0,
#    'amounts': 5520.0,
#    'totalTickets': 564,
#    'totalAmounts': 117172.0},
#   {'country': '美國',
#    'name': '蘿莉塔',
#    'releaseDate': '2022-06-17T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 1,
#    'tickets': 2,
#    'ticketChangeRate': -0.875,
#    'amounts': 440.0,
#    'totalTickets': 907,
#    'totalAmounts': 208773.0},
#   {'country': '中華民國',
#    'name': '願未央',
#    'releaseDate': '2022-03-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 1,
#    'tickets': 37,
#    'ticketChangeRate': 1.0,
#    'amounts': 4410.0,
#    'totalTickets': 2441,
#    'totalAmounts': 512088.0},
#   {'country': '中華民國',
#    'name': '尋找神話之鳥',
#    'releaseDate': '2021-12-17T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': '鴻奇文化事業有限公司',
#    'theaterCount': 2,
#    'tickets': 331,
#    'ticketChangeRate': -0.7710926694329184,
#    'amounts': 76820.0,
#    'totalTickets': 9068,
#    'totalAmounts': 1924889.0},
#   {'country': '中華民國',
#    'name': '兜兜風',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '月晴映像有限公司',
#    'produce': '月晴映像有限公司,寒山拾得有限公司,高雄人',
#    'theaterCount': 23,
#    'tickets': 2008,
#    'ticketChangeRate': -0.19744204636290968,
#    'amounts': 453595.0,
#    'totalTickets': 4510,
#    'totalAmounts': 1013475.0},
#   {'country': '中華民國',
#    'name': '有你相伴的旅程',
#    'releaseDate': '2021-12-10T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': '財團法人天主教失智老人社會福利基金會',
#    'theaterCount': 1,
#    'tickets': 305,
#    'ticketChangeRate': 1.0,
#    'amounts': 67100.0,
#    'totalTickets': 4560,
#    'totalAmounts': 998379.0},
#   {'country': '中華民國',
#    'name': '我記得',
#    'releaseDate': '2021-12-24T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 1,
#    'tickets': 41,
#    'ticketChangeRate': 1.0,
#    'amounts': 3550.0,
#    'totalTickets': 2211,
#    'totalAmounts': 473663.0},
#   {'country': '法國',
#    'name': '幸福知音',
#    'releaseDate': '2022-02-11T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'FREANCE TELEVISIONS DISTRIBUTION',
#    'theaterCount': 1,
#    'tickets': 110,
#    'ticketChangeRate': 1.0,
#    'amounts': 12717.0,
#    'totalTickets': 575,
#    'totalAmounts': 97655.0},
#   {'country': '義大利',
#    'name': '戰地夜曲',
#    'releaseDate': '2022-07-01T00:00:00',
#    'issue': '佳映娛樂國際股份有限公司',
#    'produce': 'The Match Factory GmbH',
#    'theaterCount': 1,
#    'tickets': 48,
#    'ticketChangeRate': -0.07692307692307693,
#    'amounts': 7680.0,
#    'totalTickets': 239,
#    'totalAmounts': 48345.0},
#   {'country': '美國',
#    'name': '闇黑電話',
#    'releaseDate': '2022-07-01T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 4,
#    'tickets': 85,
#    'ticketChangeRate': -0.9938668013565193,
#    'amounts': 9487.0,
#    'totalTickets': 33050,
#    'totalAmounts': 7987082.0},
#   {'country': '中華民國',
#    'name': '初戀慢半拍',
#    'releaseDate': '2022-08-24T00:00:00',
#    'issue': '香港商甲上娛樂有限公司台灣分公司',
#    'produce': '台灣大哥大股份有限公司 ,台北真好電影股份有限公司 ,良人行影業有限公司 ,宏將影業有限公司 ,時創影業股份有限公司,得利影視股份有限公司 ,聚星文創娛樂事業股份有限公司,喜滿客京華影城股份有限公司 ,威威巖娛樂製作有限公司 ,奇幻娛樂國際股份有限公司 ',
#    'theaterCount': 8,
#    'tickets': 364,
#    'ticketChangeRate': -0.9883713500734778,
#    'amounts': 54320.0,
#    'totalTickets': 31666,
#    'totalAmounts': 7584369.0},
#   {'country': '挪威',
#    'name': '世界上最爛的人',
#    'releaseDate': '2021-12-31T00:00:00',
#    'issue': '好威映象有限公司',
#    'produce': 'MK2',
#    'theaterCount': 1,
#    'tickets': 20,
#    'ticketChangeRate': -0.9283154121863799,
#    'amounts': 4080.0,
#    'totalTickets': 25939,
#    'totalAmounts': 6231285.0},
#   {'country': '波蘭',
#    'name': '機遇之歌：數位修復版',
#    'releaseDate': '2022-08-28T00:00:00',
#    'issue': '光年映畫有限公司',
#    'produce': 'MK2 FILMS',
#    'theaterCount': 3,
#    'tickets': 153,
#    'ticketChangeRate': -0.947906026557712,
#    'amounts': 36250.0,
#    'totalTickets': 3090,
#    'totalAmounts': 683808.0},
#   {'country': '中華民國',
#    'name': '藏匿處',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '春暉映像有限公司',
#    'produce': '影格電影有限公司',
#    'theaterCount': 2,
#    'tickets': 15,
#    'ticketChangeRate': -0.9975794739390027,
#    'amounts': 3380.0,
#    'totalTickets': 5184,
#    'totalAmounts': 1203612.0},
#   {'country': '日本',
#    'name': '神隱少女(日文版)',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '香港商甲上娛樂有限公司台灣分公司',
#    'produce': 'Studio Ghibli Inc.',
#    'theaterCount': 70,
#    'tickets': 7263,
#    'ticketChangeRate': -0.8754650983350766,
#    'amounts': 1797795.0,
#    'totalTickets': 65584,
#    'totalAmounts': 16258900.0},
#   {'country': '日本',
#    'name': '尋人啟弒',
#    'releaseDate': '2022-06-17T00:00:00',
#    'issue': '光年映畫有限公司',
#    'produce': 'ASMIK ACE,INC.',
#    'theaterCount': 2,
#    'tickets': 118,
#    'ticketChangeRate': -0.8413978494623656,
#    'amounts': 13431.0,
#    'totalTickets': 4799,
#    'totalAmounts': 1036440.0},
#   {'country': '香港',
#    'name': '阮玲玉',
#    'releaseDate': '1991-11-29T00:00:00',
#    'issue': '香港商甲上娛樂有限公司台灣分公司',
#    'produce': 'FORTUNE STAR MEDIA LIMITED',
#    'theaterCount': 17,
#    'tickets': 2736,
#    'ticketChangeRate': 1.0,
#    'amounts': 682100.0,
#    'totalTickets': 3434,
#    'totalAmounts': 836285.0},
#   {'country': '中華民國',
#    'name': '女優 摔吧！',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '滿滿額娛樂股份有限公司',
#    'produce': '滿滿額娛樂股份有限公司,上作娛樂有限公司',
#    'theaterCount': 47,
#    'tickets': 8987,
#    'ticketChangeRate': 1.0,
#    'amounts': 1909858.0,
#    'totalTickets': 8987,
#    'totalAmounts': 1909858.0},
#   {'country': '日本',
#    'name': '接棒家族',
#    'releaseDate': '2022-03-11T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 1,
#    'tickets': 140,
#    'ticketChangeRate': 1.0,
#    'amounts': 32300.0,
#    'totalTickets': 3649,
#    'totalAmounts': 858838.0},
#   {'country': '美國',
#    'name': '心碎效應',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 28,
#    'tickets': 254,
#    'ticketChangeRate': -0.6334776334776335,
#    'amounts': 57869.0,
#    'totalTickets': 947,
#    'totalAmounts': 226695.0},
#   {'country': '加拿大',
#    'name': '沉默呼聲',
#    'releaseDate': '2022-08-12T00:00:00',
#    'issue': '漂流木制作影視有限公司',
#    'produce': 'Flying Clound Production Inc.',
#    'theaterCount': 12,
#    'tickets': 2282,
#    'ticketChangeRate': -0.8488040813622209,
#    'amounts': 488305.0,
#    'totalTickets': 17375,
#    'totalAmounts': 3864178.0},
#   {'country': '英國',
#    'name': '餐廳失控夜',
#    'releaseDate': '2022-04-01T00:00:00',
#    'issue': '傳影互動股份有限公司',
#    'produce': 'CHARADES',
#    'theaterCount': 1,
#    'tickets': 121,
#    'ticketChangeRate': -0.4622222222222222,
#    'amounts': 6655.0,
#    'totalTickets': 3587,
#    'totalAmounts': 755164.0},
#   {'country': '美國',
#    'name': '小小兵2:格魯的崛起',
#    'releaseDate': '2022-07-20T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 28,
#    'tickets': 5951,
#    'ticketChangeRate': -0.9899534729819159,
#    'amounts': 1151602.0,
#    'totalTickets': 598210,
#    'totalAmounts': 147319137.0},
#   {'country': '中華民國',
#    'name': '我心我行',
#    'releaseDate': '2022-11-11T00:00:00',
#    'issue': '三乘影像股份有限公司',
#    'produce': '三乘影像股份有限公司,藝碩文創股份有限公司,許芳宜＆藝術家',
#    'theaterCount': 30,
#    'tickets': 21136,
#    'ticketChangeRate': 31.31804281345566,
#    'amounts': 4637939.0,
#    'totalTickets': 17825,
#    'totalAmounts': 3917829.0},
#   {'country': '香港',
#    'name': '神探大戰',
#    'releaseDate': '2022-08-19T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': '英皇影業有限公司, 英皇(北京)影視文化傳媒有限公司,北京上獅文化傳播有限公司,上海淘票票影視文化有限公司,華文映像(北京)影業有限公司',
#    'theaterCount': 7,
#    'tickets': 1488,
#    'ticketChangeRate': -0.9189454188909467,
#    'amounts': 142651.0,
#    'totalTickets': 19099,
#    'totalAmounts': 4246659.0},
#   {'country': '美國',
#    'name': '終極交戰',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 1,
#    'tickets': 5,
#    'ticketChangeRate': -0.9967845659163987,
#    'amounts': 1205.0,
#    'totalTickets': 1560,
#    'totalAmounts': 371355.0},
#   {'country': '中華民國',
#    'name': '幻日手記 ',
#    'releaseDate': '2022-10-21T00:00:00',
#    'issue': '飛望影像有限公司',
#    'produce': '飛望影像有限公司,財團法人公共電視文化事業基金會,駕絲齋影像美術設計,登月人影業有限公司,Exocorpus Productions',
#    'theaterCount': 4,
#    'tickets': 177,
#    'ticketChangeRate': 1.0,
#    'amounts': 39280.0,
#    'totalTickets': 177,
#    'totalAmounts': 39280.0},
#   {'country': '日本',
#    'name': '電影版 如果30歲還是處男，似乎就能成為魔法師',
#    'releaseDate': '2022-04-08T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'TV TOKYO CORPORATION',
#    'theaterCount': 1,
#    'tickets': 57,
#    'ticketChangeRate': -0.05,
#    'amounts': 13680.0,
#    'totalTickets': 46609,
#    'totalAmounts': 11235779.0},
#   {'country': '日本',
#    'name': '第一人夫',
#    'releaseDate': '2022-05-20T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': 'NIKKATSU CORPORATION',
#    'theaterCount': 2,
#    'tickets': 128,
#    'ticketChangeRate': -0.030303030303030304,
#    'amounts': 15230.0,
#    'totalTickets': 1085,
#    'totalAmounts': 205564.0},
#   {'country': '韓國',
#    'name': '超跑斯特拉',
#    'releaseDate': '2022-04-29T00:00:00',
#    'issue': '英屬維京群島商高捷全球開發有限公司 台灣分公司',
#    'produce': 'FINECUT CO.,LTD',
#    'theaterCount': 1,
#    'tickets': 27,
#    'ticketChangeRate': -0.9483747609942639,
#    'amounts': 2930.0,
#    'totalTickets': 3464,
#    'totalAmounts': 729431.0},
#   {'country': '法國',
#    'name': '藍色是最溫暖的顏色',
#    'releaseDate': '2022-05-27T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 1,
#    'tickets': 9,
#    'ticketChangeRate': 1.0,
#    'amounts': 2200.0,
#    'totalTickets': 456,
#    'totalAmounts': 110909.0},
#   {'country': '美國',
#    'name': '超級救援狗',
#    'releaseDate': '2022-07-10T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Film Holding Co.',
#    'theaterCount': 1,
#    'tickets': 236,
#    'ticketChangeRate': 1.9135802469135803,
#    'amounts': 26180.0,
#    'totalTickets': 317,
#    'totalAmounts': 34575.0},
#   {'country': '美國',
#    'name': '小行星獵人',
#    'releaseDate': '2022-07-03T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Film Holding Co.',
#    'theaterCount': 1,
#    'tickets': 9,
#    'ticketChangeRate': -0.6086956521739131,
#    'amounts': 1080.0,
#    'totalTickets': 36,
#    'totalAmounts': 4090.0},
#   {'country': '美國',
#    'name': '回歸野性',
#    'releaseDate': '2022-07-17T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Corporation.',
#    'theaterCount': 1,
#    'tickets': 10,
#    'ticketChangeRate': -0.6296296296296297,
#    'amounts': 1160.0,
#    'totalTickets': 37,
#    'totalAmounts': 3595.0},
#   {'country': '美國',
#    'name': '深海獵奇',
#    'releaseDate': '2022-07-09T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Corporation.',
#    'theaterCount': 1,
#    'tickets': 136,
#    'ticketChangeRate': 0.7,
#    'amounts': 15200.0,
#    'totalTickets': 216,
#    'totalAmounts': 23590.0},
#   {'country': '美國',
#    'name': '最後的冰川',
#    'releaseDate': '2022-07-02T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Corporation',
#    'theaterCount': 1,
#    'tickets': 19,
#    'ticketChangeRate': -0.8716216216216216,
#    'amounts': 2100.0,
#    'totalTickets': 168,
#    'totalAmounts': 13165.0},
#   {'country': '美國',
#    'name': '馬達加斯加：狐猴之島',
#    'releaseDate': '2022-07-16T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Corporation.',
#    'theaterCount': 1,
#    'tickets': 110,
#    'ticketChangeRate': 1.894736842105263,
#    'amounts': 12160.0,
#    'totalTickets': 148,
#    'totalAmounts': 16050.0},
#   {'country': '美國',
#    'name': '哈勃望遠鏡',
#    'releaseDate': '2019-02-01T00:00:00',
#    'issue': '豪華大戲院股份有限公司',
#    'produce': 'IMAX Corporation.',
#    'theaterCount': 2,
#    'tickets': 26,
#    'ticketChangeRate': -0.13333333333333333,
#    'amounts': 3210.0,
#    'totalTickets': 56,
#    'totalAmounts': 6110.0},
#   {'country': '美國',
#    'name': '奇異博士2：失控多重宇宙',
#    'releaseDate': '2022-05-04T00:00:00',
#    'issue': '台灣華特迪士尼股份有限公司',
#    'produce': 'BUENA VISTA INTERNATIONAL,INC.',
#    'theaterCount': 1,
#    'tickets': 15,
#    'ticketChangeRate': -0.9956797235023042,
#    'amounts': 825.0,
#    'totalTickets': 931021,
#    'totalAmounts': 244509640.0},
#   {'country': '美國',
#    'name': '探戈行不行',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '春暉映像有限公司',
#    'produce': 'Vision Films,Inc',
#    'theaterCount': 3,
#    'tickets': 319,
#    'ticketChangeRate': -0.5706594885598923,
#    'amounts': 34235.0,
#    'totalTickets': 950,
#    'totalAmounts': 164439.0},
#   {'country': '美國',
#    'name': '捍衛戰士: 獨行俠',
#    'releaseDate': '2022-05-23T00:00:00',
#    'issue': '美商美國派拉蒙影片股份有限公司台灣分公司',
#    'produce': 'PARAMOUNT PICTURES CORPORATION',
#    'theaterCount': 62,
#    'tickets': 20796,
#    'ticketChangeRate': -0.9600599983483169,
#    'amounts': 6280328.0,
#    'totalTickets': 2681805,
#    'totalAmounts': 734339947.0},
#   {'country': '中華民國',
#    'name': '一家子兒咕咕叫',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '原子映象有限公司',
#    'produce': '六六喜喜股份有限公司,原子映象有限公司,高雄人,臺中拍',
#    'theaterCount': 56,
#    'tickets': 17167,
#    'ticketChangeRate': 1.0,
#    'amounts': 3727254.0,
#    'totalTickets': 16866,
#    'totalAmounts': 3658874.0},
#   {'country': '美國',
#    'name': '侏羅紀世界: 統霸天下',
#    'releaseDate': '2022-06-08T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 5,
#    'tickets': 880,
#    'ticketChangeRate': -0.9927394536438867,
#    'amounts': 67190.0,
#    'totalTickets': 1278260,
#    'totalAmounts': 334075247.0},
#   {'country': '中華民國',
#    'name': '神人之家',
#    'releaseDate': '2022-08-11T00:00:00',
#    'issue': '飛望影像有限公司',
#    'produce': '飛望影像有限公司,文化內容策進院,Films de Force Majeure',
#    'theaterCount': 36,
#    'tickets': 15882,
#    'ticketChangeRate': 29.13662239089184,
#    'amounts': 3682234.0,
#    'totalTickets': 16409,
#    'totalAmounts': 3799564.0},
#   {'country': '中華民國',
#    'name': '孫行者傳',
#    'releaseDate': '2022-10-13T00:00:00',
#    'issue': '數位領域電影文化股份有限公司',
#    'produce': '數位領域電影文化股份有限公司',
#    'theaterCount': 47,
#    'tickets': 6666,
#    'ticketChangeRate': 1.0,
#    'amounts': 1341685.0,
#    'totalTickets': 6666,
#    'totalAmounts': 1341685.0},
#   {'country': '泰國',
#    'name': '淒厲人僧：卡到陰',
#    'releaseDate': '2022-05-20T00:00:00',
#    'issue': '水元素文化傳媒有限公司',
#    'produce': 'Five Star Production Company Limited',
#    'theaterCount': 1,
#    'tickets': 4,
#    'ticketChangeRate': -0.9259259259259259,
#    'amounts': 560.0,
#    'totalTickets': 2314,
#    'totalAmounts': 529394.0},
#   {'country': '烏克蘭',
#    'name': '格列佛遊記：重返小人國',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '可樂藝術文創股份有限公司',
#    'produce': 'All Rights Entertainment.Ltd',
#    'theaterCount': 1,
#    'tickets': 53,
#    'ticketChangeRate': -0.9772043010752688,
#    'amounts': 5750.0,
#    'totalTickets': 2209,
#    'totalAmounts': 510025.0},
#   {'country': '義大利',
#    'name': '愛在書店相遇時',
#    'releaseDate': '2022-06-02T00:00:00',
#    'issue': '東昊影業有限公司',
#    'produce': 'True Colours',
#    'theaterCount': 1,
#    'tickets': 102,
#    'ticketChangeRate': 0.25925925925925924,
#    'amounts': 5610.0,
#    'totalTickets': 811,
#    'totalAmounts': 141789.0},
#   {'country': '美國',
#    'name': '大開眼戒',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 3,
#    'tickets': 12,
#    'ticketChangeRate': -0.9926108374384236,
#    'amounts': 2575.0,
#    'totalTickets': 1636,
#    'totalAmounts': 399338.0},
#   {'country': '印尼',
#    'name': '娜娜：逝水年華',
#    'releaseDate': '2022-07-08T00:00:00',
#    'issue': '前景娛樂有限公司',
#    'produce': 'WILD BUNCH INTERNATIONAL',
#    'theaterCount': 1,
#    'tickets': 3,
#    'ticketChangeRate': -0.9935897435897436,
#    'amounts': 600.0,
#    'totalTickets': 623,
#    'totalAmounts': 130877.0},
#   {'country': '英國',
#    'name': '伊恩•麥克連 80歲個人秀巡迴演出（英國國家劇院現場）',
#    'releaseDate': '2022-06-11T00:00:00',
#    'issue': '威秀影城股份有限公司',
#    'produce': 'Royal National Theatre',
#    'theaterCount': 6,
#    'tickets': 93,
#    'ticketChangeRate': -0.8421052631578947,
#    'amounts': 66380.0,
#    'totalTickets': 847,
#    'totalAmounts': 587880.0},
#   {'country': '日本',
#    'name': '偷情連載中',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': 'NIKKATSU CORPORATION',
#    'theaterCount': 1,
#    'tickets': 128,
#    'ticketChangeRate': -0.8403990024937655,
#    'amounts': 7040.0,
#    'totalTickets': 930,
#    'totalAmounts': 183929.0},
#   {'country': '芬蘭',
#    'name': '當女孩戀愛時',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '光年映畫有限公司',
#    'produce': 'LevelK ApS',
#    'theaterCount': 1,
#    'tickets': 55,
#    'ticketChangeRate': -0.956828885400314,
#    'amounts': 6280.0,
#    'totalTickets': 1329,
#    'totalAmounts': 276983.0},
#   {'country': '日本',
#    'name': '名偵探柯南 萬聖節的新娘',
#    'releaseDate': '2022-06-30T00:00:00',
#    'issue': '普威爾國際股份有限公司',
#    'produce': '株式会社トムス・エンタテインメント',
#    'theaterCount': 10,
#    'tickets': 2057,
#    'ticketChangeRate': -0.9920042602483071,
#    'amounts': 460066.0,
#    'totalTickets': 481860,
#    'totalAmounts': 121054495.0},
#   {'country': '黎巴嫩',
#    'name': '黎巴嫩的天空',
#    'releaseDate': '2022-06-10T00:00:00',
#    'issue': '薩摩亞商雄讚股份有限公司台灣分公司',
#    'produce': '1982 Productions,LLC',
#    'theaterCount': 1,
#    'tickets': 66,
#    'ticketChangeRate': 0.17857142857142858,
#    'amounts': 10560.0,
#    'totalTickets': 493,
#    'totalAmounts': 96874.0},
#   {'country': '美國',
#    'name': '巴斯光年(英文版)',
#    'releaseDate': '2022-06-17T00:00:00',
#    'issue': '台灣華特迪士尼股份有限公司',
#    'produce': 'BUENA VISTA INTERNATIONAL,INC.',
#    'theaterCount': 3,
#    'tickets': 288,
#    'ticketChangeRate': -0.985356180403722,
#    'amounts': 43610.0,
#    'totalTickets': 170787,
#    'totalAmounts': 42101042.0},
#   {'country': '英國',
#    'name': '利奥波德城（英國國家劇院現場）',
#    'releaseDate': '2022-06-14T00:00:00',
#    'issue': '威秀影城股份有限公司',
#    'produce': 'Royal National Theatre',
#    'theaterCount': 3,
#    'tickets': 33,
#    'ticketChangeRate': -0.8583690987124464,
#    'amounts': 22840.0,
#    'totalTickets': 313,
#    'totalAmounts': 202260.0},
#   {'country': '波蘭',
#    'name': '拜金女王的性愛派對',
#    'releaseDate': '2022-06-24T00:00:00',
#    'issue': '仲業股份有限公司',
#    'produce': 'Cinema Management Group,LLC',
#    'theaterCount': 1,
#    'tickets': 12,
#    'ticketChangeRate': -0.9880597014925373,
#    'amounts': 1920.0,
#    'totalTickets': 4699,
#    'totalAmounts': 1016821.0},
#   {'country': '美國',
#    'name': '貓王艾維斯',
#    'releaseDate': '2022-06-23T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 3,
#    'tickets': 363,
#    'ticketChangeRate': -0.9536457668241604,
#    'amounts': 44050.0,
#    'totalTickets': 39374,
#    'totalAmounts': 9848144.0},
#   {'country': '中國大陸',
#    'name': '于堇：蘭心大劇院',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '峻龍國際有限公司',
#    'produce': '北京千易時代文化傳媒有限公司,霍爾果斯佰安影業有限公司,浙江天意影視有限公司,伊犁卓然影業有限公司,霍爾果斯聚合影聯文化傳媒有限公司,上海千易源文化傳媒有限公司,凡魚傳媒(北京)有限公司,上海依英影視傳媒有限公司',
#    'theaterCount': 1,
#    'tickets': 70,
#    'ticketChangeRate': -0.9593967517401392,
#    'amounts': 8320.0,
#    'totalTickets': 1794,
#    'totalAmounts': 377940.0},
#   {'country': '日本',
#    'name': '只是現在不走運而已',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'GAGA Corporation',
#    'theaterCount': 1,
#    'tickets': 124,
#    'ticketChangeRate': -0.7268722466960352,
#    'amounts': 19840.0,
#    'totalTickets': 578,
#    'totalAmounts': 116816.0},
#   {'country': '印度',
#    'name': '偉大的印度廚房',
#    'releaseDate': '2022-07-08T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'MANKIND CINEMAS',
#    'theaterCount': 2,
#    'tickets': 311,
#    'ticketChangeRate': -0.8278915329275042,
#    'amounts': 22390.0,
#    'totalTickets': 2224,
#    'totalAmounts': 371605.0},
#   {'country': '日本',
#    'name': '婚顧女王',
#    'releaseDate': '2022-07-15T00:00:00',
#    'issue': '中影股份有限公司',
#    'produce': '松竹 株式會社  Shochiku Co.,Ltd.',
#    'theaterCount': 2,
#    'tickets': 77,
#    'ticketChangeRate': -0.964548802946593,
#    'amounts': 13280.0,
#    'totalTickets': 2249,
#    'totalAmounts': 493877.0},
#   {'country': '法國',
#    'name': '失業風暴',
#    'releaseDate': '2022-07-15T00:00:00',
#    'issue': '可樂藝術文創股份有限公司',
#    'produce': 'France Televisions Distribution',
#    'theaterCount': 2,
#    'tickets': 101,
#    'ticketChangeRate': -0.9504901960784313,
#    'amounts': 22140.0,
#    'totalTickets': 2141,
#    'totalAmounts': 397574.0},
#   {'country': '日本',
#    'name': '角落小夥伴電影版：藍色月夜的魔法之子(日語版)',
#    'releaseDate': '2022-08-05T00:00:00',
#    'issue': '威視股份有限公司',
#    'produce': 'ASMIK ACE,INC.',
#    'theaterCount': 21,
#    'tickets': 2769,
#    'ticketChangeRate': -0.9526593834948966,
#    'amounts': 703692.0,
#    'totalTickets': 60551,
#    'totalAmounts': 14813153.0},
#   {'country': '美國',
#    'name': '喜悅：達賴喇嘛遇見屠圖主教',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '佳映娛樂國際股份有限公司',
#    'produce': 'ro*co films international, llc',
#    'theaterCount': 7,
#    'tickets': 1287,
#    'ticketChangeRate': -0.9043336058871627,
#    'amounts': 271240.0,
#    'totalTickets': 14740,
#    'totalAmounts': 3395702.0},
#   {'country': '香港',
#    'name': '花樣年華 4K數位修復版',
#    'releaseDate': '2022-09-03T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': 'Jet Tone Films Limited,春光映畫,PARADIS FILMS',
#    'theaterCount': 22,
#    'tickets': 5533,
#    'ticketChangeRate': -0.38254659078227876,
#    'amounts': 1322347.0,
#    'totalTickets': 14494,
#    'totalAmounts': 3636734.0},
#   {'country': '美國',
#    'name': '雷神索爾：愛與雷霆',
#    'releaseDate': '2022-07-06T00:00:00',
#    'issue': '台灣華特迪士尼股份有限公司',
#    'produce': 'BUENA VISTA INTERNATIONAL,INC.',
#    'theaterCount': 6,
#    'tickets': 2944,
#    'ticketChangeRate': -0.9954616716278941,
#    'amounts': 277382.0,
#    'totalTickets': 862955,
#    'totalAmounts': 225303582.0},
#   {'country': '香港',
#    'name': '闔家辣',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '香港商甲上娛樂有限公司台灣分公司',
#    'produce': '金銀島製作有限公司,天下一電影製作有限公司,寰亞電影製作有限公司,香港電影發展基金',
#    'theaterCount': 1,
#    'tickets': 16,
#    'ticketChangeRate': -0.9925754060324826,
#    'amounts': 2560.0,
#    'totalTickets': 2171,
#    'totalAmounts': 504321.0},
#   {'country': '美國',
#    'name': '子彈列車',
#    'releaseDate': '2022-08-03T00:00:00',
#    'issue': '美商台灣索尼影業發行股份有限公司台灣分公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 68,
#    'tickets': 5888,
#    'ticketChangeRate': -0.9869093011105305,
#    'amounts': 1240407.0,
#    'totalTickets': 455673,
#    'totalAmounts': 117559321.0},
#   {'country': '中華民國',
#    'name': '哈勇家',
#    'releaseDate': '2022-08-12T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': '華映娛樂股份有限公司,氧氣電影有限公司,中環國際娛樂事業股份有限公司,星泰國際娛樂股份有限公司,得藝文創國際股份有限公司,凡宇興業有限公司,樂到家國際娛樂股份有限公司,鏡文學股份有限公司',
#    'theaterCount': 84,
#    'tickets': 57507,
#    'ticketChangeRate': 38.30758714969241,
#    'amounts': 12709140.0,
#    'totalTickets': 58970,
#    'totalAmounts': 13037310.0},
#   {'country': '香港',
#    'name': '七人樂隊',
#    'releaseDate': '2022-07-22T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': '寰亞電影製作有限公司,中影寰亞音像製品有限公司,星光聯盟影業無錫有限公司,8028控股有限公司,北京真之影文化傳媒有限公司',
#    'theaterCount': 1,
#    'tickets': 88,
#    'ticketChangeRate': -0.9433354797166774,
#    'amounts': 14080.0,
#    'totalTickets': 1396,
#    'totalAmounts': 315774.0},
#   {'country': '日本',
#    'name': '特『刀劍亂舞-花丸-』～雪之卷～',
#    'releaseDate': '2022-07-29T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'Marvelous Inc.',
#    'theaterCount': 8,
#    'tickets': 683,
#    'ticketChangeRate': -0.8592333058532564,
#    'amounts': 133875.0,
#    'totalTickets': 5305,
#    'totalAmounts': 1304333.0},
#   {'country': '香港',
#    'name': '繼園臺七號',
#    'releaseDate': '2022-09-21T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': '花生映社有限公司',
#    'theaterCount': 6,
#    'tickets': 504,
#    'ticketChangeRate': 0.4318181818181818,
#    'amounts': 149742.0,
#    'totalTickets': 856,
#    'totalAmounts': 255397.0},
#   {'country': '香港',
#    'name': '美少年之戀',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': '花生映社有限公司',
#    'theaterCount': 6,
#    'tickets': 216,
#    'ticketChangeRate': 0.09644670050761421,
#    'amounts': 53352.0,
#    'totalTickets': 413,
#    'totalAmounts': 99692.0},
#   {'country': '美國',
#    'name': '孤兒怨2：最黑暗的過去',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '寶嘉租賃股份有限公司',
#    'produce': 'FILM,TV HOUSE LIMITED',
#    'theaterCount': 50,
#    'tickets': 2163,
#    'ticketChangeRate': -0.9707370528708263,
#    'amounts': 465500.0,
#    'totalTickets': 76079,
#    'totalAmounts': 18767755.0},
#   {'country': '中華民國',
#    'name': '民雄鬼屋',
#    'releaseDate': '2022-07-29T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': '后花園數位影像製作有限公司,馬棋朵數位影像製作有限公司,采昌國際多媒體股份有限公司,皮諾丘電影事業有限公司,煉金術電影事業有限公司,罡風創意映像有限公司,有樂股份有限公司',
#    'theaterCount': 4,
#    'tickets': 612,
#    'ticketChangeRate': -0.9949222995677317,
#    'amounts': 59351.0,
#    'totalTickets': 120366,
#    'totalAmounts': 29483926.0},
#   {'country': '中華民國',
#    'name': '舞徑',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '好威映象有限公司',
#    'produce': '楊偉新',
#    'theaterCount': 16,
#    'tickets': 1014,
#    'ticketChangeRate': -0.7865712481582825,
#    'amounts': 239159.0,
#    'totalTickets': 3260,
#    'totalAmounts': 769589.0},
#   {'country': '美國',
#    'name': 'DC超級寵物軍團(英文版)',
#    'releaseDate': '2022-08-09T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 7,
#    'tickets': 450,
#    'ticketChangeRate': -0.9914460052844678,
#    'amounts': 42825.0,
#    'totalTickets': 53057,
#    'totalAmounts': 12544161.0},
#   {'country': '法國',
#    'name': '瑪歌皇后 數位修復版',
#    'releaseDate': '2022-10-14T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 16,
#    'tickets': 737,
#    'ticketChangeRate': 1.0,
#    'amounts': 171559.0,
#    'totalTickets': 737,
#    'totalAmounts': 171559.0},
#   {'country': '法國',
#    'name': '就在今夜',
#    'releaseDate': '2022-07-29T00:00:00',
#    'issue': '東昊影業有限公司',
#    'produce': 'MK2 Films',
#    'theaterCount': 2,
#    'tickets': 215,
#    'ticketChangeRate': -0.853641933287951,
#    'amounts': 30107.0,
#    'totalTickets': 1684,
#    'totalAmounts': 359178.0},
#   {'country': '日本',
#    'name': '蠟筆小新：幽靈忍者珍風傳',
#    'releaseDate': '2022-08-04T00:00:00',
#    'issue': '木棉花國際股份有限公司',
#    'produce': 'ADK EMOTIOS INC.',
#    'theaterCount': 23,
#    'tickets': 3893,
#    'ticketChangeRate': -0.9692199433893641,
#    'amounts': 962712.0,
#    'totalTickets': 130371,
#    'totalAmounts': 31937273.0},
#   {'country': '美國',
#    'name': '沼澤謀殺案',
#    'releaseDate': '2022-10-07T00:00:00',
#    'issue': '美商台灣索尼影業發行股份有限公司台灣分公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 95,
#    'tickets': 22520,
#    'ticketChangeRate': 1.0,
#    'amounts': 5360490.0,
#    'totalTickets': 19189,
#    'totalAmounts': 4583335.0},
#   {'country': '英國',
#    'name': '偷香 數位修復版',
#    'releaseDate': '2022-08-05T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 1,
#    'tickets': 1,
#    'ticketChangeRate': -0.99609375,
#    'amounts': 220.0,
#    'totalTickets': 257,
#    'totalAmounts': 50692.0},
#   {'country': '波蘭',
#    'name': '大獲拳勝',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '燕翼企業有限公司',
#    'produce': 'LOCO FILMS',
#    'theaterCount': 2,
#    'tickets': 276,
#    'ticketChangeRate': -0.7203647416413373,
#    'amounts': 30680.0,
#    'totalTickets': 1263,
#    'totalAmounts': 239756.0},
#   {'country': '美國',
#    'name': '不!',
#    'releaseDate': '2022-08-12T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 8,
#    'tickets': 1155,
#    'ticketChangeRate': -0.9770130955697967,
#    'amounts': 119215.0,
#    'totalTickets': 51401,
#    'totalAmounts': 13276893.0},
#   {'country': '中華民國',
#    'name': '無岸之河',
#    'releaseDate': '2015-12-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 36,
#    'ticketChangeRate': 1.0,
#    'amounts': 8445.0,
#    'totalTickets': 36,
#    'totalAmounts': 8445.0},
#   {'country': '中華民國',
#    'name': '兩地',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 52,
#    'ticketChangeRate': 1.0,
#    'amounts': 11840.0,
#    'totalTickets': 52,
#    'totalAmounts': 11840.0},
#   {'country': '中華民國',
#    'name': '他還年輕',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 15,
#    'tickets': 2710,
#    'ticketChangeRate': -0.6891845395114119,
#    'amounts': 595965.0,
#    'totalTickets': 9252,
#    'totalAmounts': 2041902.0},
#   {'country': '新加坡',
#    'name': '妖街皇后',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': '花生映社有限公司',
#    'theaterCount': 6,
#    'tickets': 397,
#    'ticketChangeRate': 17.904761904761905,
#    'amounts': 117463.0,
#    'totalTickets': 418,
#    'totalAmounts': 122233.0},
#   {'country': '日本',
#    'name': '擅長捉弄人的高木同學劇場版',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '木棉花國際股份有限公司',
#    'produce': 'ASMIK ACE,INC.',
#    'theaterCount': 14,
#    'tickets': 1865,
#    'ticketChangeRate': -0.9275700027185522,
#    'amounts': 495523.0,
#    'totalTickets': 27614,
#    'totalAmounts': 7366694.0},
#   {'country': '日本',
#    'name': '七五計劃',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'URBAN SALES. s.a.s (“US”)',
#    'theaterCount': 5,
#    'tickets': 185,
#    'ticketChangeRate': -0.9061390157280568,
#    'amounts': 39860.0,
#    'totalTickets': 2156,
#    'totalAmounts': 466241.0},
#   {'country': '美國',
#    'name': '天黑請斃命',
#    'releaseDate': '2022-08-19T00:00:00',
#    'issue': '美商台灣索尼影業發行股份有限公司台灣分公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 3,
#    'tickets': 452,
#    'ticketChangeRate': -0.955511811023622,
#    'amounts': 44734.0,
#    'totalTickets': 10612,
#    'totalAmounts': 2522604.0},
#   {'country': '中華民國',
#    'name': '尋找背海的人',
#    'releaseDate': '2022-09-03T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 2,
#    'tickets': 2,
#    'ticketChangeRate': -0.9473684210526315,
#    'amounts': 470.0,
#    'totalTickets': 40,
#    'totalAmounts': 9760.0},
#   {'country': '日本',
#    'name': '末日救世主',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': 'TOKYO BROADCASTING SYSTEM TELEVISION, INC.',
#    'theaterCount': 1,
#    'tickets': 34,
#    'ticketChangeRate': -0.9861394211169996,
#    'amounts': 7595.0,
#    'totalTickets': 2487,
#    'totalAmounts': 570570.0},
#   {'country': '日本',
#    'name': '北齋：浮世繪傳奇',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '傳影互動股份有限公司',
#    'produce': 'SDP INC.',
#    'theaterCount': 3,
#    'tickets': 251,
#    'ticketChangeRate': -0.9588322125635559,
#    'amounts': 47940.0,
#    'totalTickets': 6120,
#    'totalAmounts': 1338111.0},
#   {'country': '美國',
#    'name': '獸',
#    'releaseDate': '2022-08-19T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 5,
#    'tickets': 928,
#    'ticketChangeRate': -0.9355510799361066,
#    'amounts': 79298.0,
#    'totalTickets': 15327,
#    'totalAmounts': 3494845.0},
#   {'country': '中華民國',
#    'name': '如歌的行板',
#    'releaseDate': '2015-12-18T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 55,
#    'ticketChangeRate': 1.0,
#    'amounts': 12615.0,
#    'totalTickets': 55,
#    'totalAmounts': 12615.0},
#   {'country': '韓國',
#    'name': '緊急迫降',
#    'releaseDate': '2022-08-12T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 31,
#    'tickets': 1642,
#    'ticketChangeRate': -0.9910045141780252,
#    'amounts': 369418.0,
#    'totalTickets': 184178,
#    'totalAmounts': 45065924.0},
#   {'country': '中華民國',
#    'name': '如霧起時',
#    'releaseDate': '2022-10-29T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 122,
#    'ticketChangeRate': 1.0,
#    'amounts': 31930.0,
#    'totalTickets': 122,
#    'totalAmounts': 31930.0},
#   {'country': '日本',
#    'name': '劇場版 五等分的新娘',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 27,
#    'tickets': 4866,
#    'ticketChangeRate': -0.7999177631578948,
#    'amounts': 1142273.0,
#    'totalTickets': 29186,
#    'totalAmounts': 7341179.0},
#   {'country': '挪威',
#    'name': '愛重奏',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '好威映象有限公司',
#    'produce': 'TRUSTNORDISK APS',
#    'theaterCount': 1,
#    'tickets': 57,
#    'ticketChangeRate': -0.9641057934508817,
#    'amounts': 11630.0,
#    'totalTickets': 1645,
#    'totalAmounts': 378998.0},
#   {'country': '香港',
#    'name': '流金歲月',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': '花生映社有限公司,中央電影事業股份有限公司',
#    'theaterCount': 4,
#    'tickets': 53,
#    'ticketChangeRate': -0.6602564102564102,
#    'amounts': 12999.0,
#    'totalTickets': 209,
#    'totalAmounts': 48220.0},
#   {'country': '日本',
#    'name': '航海王劇場版 : 紅髮歌姬',
#    'releaseDate': '2022-08-13T00:00:00',
#    'issue': '薩摩亞商雄讚股份有限公司台灣分公司',
#    'produce': 'TOEI ANIMATION ENTERPRISES LIMITED.',
#    'theaterCount': 94,
#    'tickets': 26995,
#    'ticketChangeRate': -0.9573765625567431,
#    'amounts': 7218734.0,
#    'totalTickets': 660332,
#    'totalAmounts': 175286007.0},
#   {'country': '法國',
#    'name': '夜色中的她',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '佳映娛樂國際股份有限公司',
#    'produce': 'CHARADES',
#    'theaterCount': 1,
#    'tickets': 62,
#    'ticketChangeRate': -0.36082474226804123,
#    'amounts': 9920.0,
#    'totalTickets': 159,
#    'totalAmounts': 31479.0},
#   {'country': '法國',
#    'name': '正發生',
#    'releaseDate': '2022-09-30T00:00:00',
#    'issue': '好威映象有限公司',
#    'produce': 'Wild Bunch International',
#    'theaterCount': 20,
#    'tickets': 4082,
#    'ticketChangeRate': 1.0,
#    'amounts': 924281.0,
#    'totalTickets': 4082,
#    'totalAmounts': 924281.0},
#   {'country': '義大利',
#    'name': '請為我在羅馬多留一天',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '海鵬影業有限公司',
#    'produce': 'VISION DISTRIBUTION S.p.A.',
#    'theaterCount': 4,
#    'tickets': 618,
#    'ticketChangeRate': -0.5573065902578797,
#    'amounts': 72930.0,
#    'totalTickets': 2014,
#    'totalAmounts': 365064.0},
#   {'country': '韓國',
#    'name': '韓山島海戰',
#    'releaseDate': '2022-08-19T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 1,
#    'tickets': 1,
#    'ticketChangeRate': -0.9999099342520039,
#    'amounts': 290.0,
#    'totalTickets': 11104,
#    'totalAmounts': 2632400.0},
#   {'country': '日本',
#    'name': '電影版 搖曳露營△ ',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '薩摩亞商羚邦(亞洲)有限公司台灣分公司',
#    'produce': 'FURYU CORPORATION',
#    'theaterCount': 49,
#    'tickets': 8294,
#    'ticketChangeRate': -0.619156947378088,
#    'amounts': 2167034.0,
#    'totalTickets': 30072,
#    'totalAmounts': 7627850.0},
#   {'country': '中華民國',
#    'name': '化城再來人',
#    'releaseDate': '2011-04-09T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 43,
#    'ticketChangeRate': 1.0,
#    'amounts': 10931.0,
#    'totalTickets': 43,
#    'totalAmounts': 10931.0},
#   {'country': '中華民國',
#    'name': '科學少女',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '華影國際影藝有限公司',
#    'produce': '東海大學,東吳大學,國立台灣師範大學,社團法人中華民國大渡山學會',
#    'theaterCount': 50,
#    'tickets': 16259,
#    'ticketChangeRate': -0.08549412227909331,
#    'amounts': 3672587.0,
#    'totalTickets': 30736,
#    'totalAmounts': 7000041.0},
#   {'country': '中華民國',
#    'name': '大俠胡金銓 第二部曲—斷腸人在天涯',
#    'releaseDate': '2022-09-03T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': '華映娛樂股份有限公司,七霞電影有限公司',
#    'theaterCount': 26,
#    'tickets': 3367,
#    'ticketChangeRate': 0.7852598091198303,
#    'amounts': 656476.0,
#    'totalTickets': 5253,
#    'totalAmounts': 1062636.0},
#   {'country': '香港',
#    'name': '玫瑰的故事',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': '花生映社有限公司',
#    'theaterCount': 6,
#    'tickets': 119,
#    'ticketChangeRate': -0.3081395348837209,
#    'amounts': 27792.0,
#    'totalTickets': 291,
#    'totalAmounts': 67090.0},
#   {'country': '中華民國',
#    'name': '大俠胡金銓 第一部曲—先知曾經來過',
#    'releaseDate': '2022-09-03T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': '華映娛樂股份有限公司,七霞電影有限公司',
#    'theaterCount': 26,
#    'tickets': 4235,
#    'ticketChangeRate': 1.2454931071049842,
#    'amounts': 882492.0,
#    'totalTickets': 6121,
#    'totalAmounts': 1288652.0},
#   {'country': '摩洛哥',
#    'name': '聽見心嘻望',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '海鵬影業有限公司',
#    'produce': 'WILD BUNCH INTERNATIONAL',
#    'theaterCount': 12,
#    'tickets': 222,
#    'ticketChangeRate': 0.39622641509433965,
#    'amounts': 46925.0,
#    'totalTickets': 381,
#    'totalAmounts': 79962.0},
#   {'country': '韓國',
#    'name': '獵首密令',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '英屬維京群島商高捷全球開發有限公司 台灣分公司',
#    'produce': 'MegaboxJoongang, Inc, PlusM.',
#    'theaterCount': 17,
#    'tickets': 1204,
#    'ticketChangeRate': -0.9644764405629481,
#    'amounts': 138912.0,
#    'totalTickets': 35097,
#    'totalAmounts': 8274617.0},
#   {'country': '日本',
#    'name': '劇場版 超時空要塞F~虛空歌姬~',
#    'releaseDate': '2022-09-07T00:00:00',
#    'issue': '水元素文化傳媒有限公司',
#    'produce': 'BIGWEST CO., LTD.',
#    'theaterCount': 14,
#    'tickets': 1040,
#    'ticketChangeRate': -0.661127403062887,
#    'amounts': 254130.0,
#    'totalTickets': 4109,
#    'totalAmounts': 1035351.0},
#   {'country': '美國',
#    'name': '三千年的渴望',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'GEM ENTERTAINMENT KFT.',
#    'theaterCount': 10,
#    'tickets': 539,
#    'ticketChangeRate': -0.9653621232568601,
#    'amounts': 125171.0,
#    'totalTickets': 16100,
#    'totalAmounts': 3909305.0},
#   {'country': '美國',
#    'name': '世紀婚魘',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '美商台灣索尼影業發行股份有限公司台灣分公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 9,
#    'tickets': 381,
#    'ticketChangeRate': -0.9682552907848692,
#    'amounts': 30785.0,
#    'totalTickets': 12383,
#    'totalAmounts': 2889454.0},
#   {'country': '英國',
#    'name': '士兵與軍官',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': 'FIREBIRD PRODUCTION LIMITED',
#    'theaterCount': 3,
#    'tickets': 75,
#    'ticketChangeRate': -0.9752066115702479,
#    'amounts': 17200.0,
#    'totalTickets': 3100,
#    'totalAmounts': 716392.0},
#   {'country': '日本',
#    'name': '特『刀劍亂舞-花丸-』～月之卷～',
#    'releaseDate': '2022-08-26T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'Marvelous Inc. \t ',
#    'theaterCount': 8,
#    'tickets': 683,
#    'ticketChangeRate': -0.8202158462753356,
#    'amounts': 133875.0,
#    'totalTickets': 4482,
#    'totalAmounts': 1100049.0},
#   {'country': '法國',
#    'name': '她和她的小主廚們',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '佳映娛樂國際股份有限公司',
#    'produce': 'CHARADES',
#    'theaterCount': 6,
#    'tickets': 138,
#    'ticketChangeRate': 0.014705882352941176,
#    'amounts': 23210.0,
#    'totalTickets': 274,
#    'totalAmounts': 52035.0},
#   {'country': '日本',
#    'name': '極道主夫 電影版',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'YOMIURI TELECASTING CORPORATION',
#    'theaterCount': 20,
#    'tickets': 143,
#    'ticketChangeRate': -0.9506044905008636,
#    'amounts': 31120.0,
#    'totalTickets': 3038,
#    'totalAmounts': 714492.0},
#   {'country': '中華民國',
#    'name': '逍遙遊',
#    'releaseDate': '2011-04-06T00:00:00',
#    'issue': '目宿媒體股份有限公司',
#    'produce': '目宿媒體股份有限公司',
#    'theaterCount': 3,
#    'tickets': 37,
#    'ticketChangeRate': 1.0,
#    'amounts': 8640.0,
#    'totalTickets': 37,
#    'totalAmounts': 8640.0},
#   {'country': '香港',
#    'name': '媽的星寵兒',
#    'releaseDate': '2022-09-02T00:00:00',
#    'issue': '英屬維京群島商高捷全球開發有限公司 台灣分公司',
#    'produce': '英皇影業有限公司 , 英皇娛樂(香港)有限公司 , 香港電影發展基金 ',
#    'theaterCount': 3,
#    'tickets': 180,
#    'ticketChangeRate': -0.895712630359212,
#    'amounts': 29797.0,
#    'totalTickets': 1906,
#    'totalAmounts': 456510.0},
#   {'country': '法國',
#    'name': '拆彈倒數30分鐘',
#    'releaseDate': '2022-09-23T00:00:00',
#    'issue': '仲業股份有限公司',
#    'produce': 'wide',
#    'theaterCount': 30,
#    'tickets': 1111,
#    'ticketChangeRate': -0.16403310759969902,
#    'amounts': 171323.0,
#    'totalTickets': 2440,
#    'totalAmounts': 457966.0},
#   {'country': '日本',
#    'name': '七龍珠超：超級英雄(日文版)',
#    'releaseDate': '2022-09-03T00:00:00',
#    'issue': '美商台灣索尼影業發行股份有限公司台灣分公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 86,
#    'tickets': 2747,
#    'ticketChangeRate': -0.9312717355950861,
#    'amounts': 676270.0,
#    'totalTickets': 42716,
#    'totalAmounts': 11311644.0},
#   {'country': '美國',
#    'name': '拉辛正傳',
#    'releaseDate': '2022-09-08T00:00:00',
#    'issue': '美商美國派拉蒙影片股份有限公司台灣分公司',
#    'produce': 'PARAMOUNT PICTURES CORPORATION',
#    'theaterCount': 61,
#    'tickets': 2140,
#    'ticketChangeRate': -0.879341452413171,
#    'amounts': 407119.0,
#    'totalTickets': 19876,
#    'totalAmounts': 4659456.0},
#   {'country': '伊朗',
#    'name': '贖罪風暴',
#    'releaseDate': '2022-10-07T00:00:00',
#    'issue': '海鵬影業有限公司',
#    'produce': 'TOTEM FILMS SAS',
#    'theaterCount': 15,
#    'tickets': 885,
#    'ticketChangeRate': 1.0,
#    'amounts': 184539.0,
#    'totalTickets': 885,
#    'totalAmounts': 184539.0},
#   {'country': '日本',
#    'name': '萌男友是柑橘色',
#    'releaseDate': '2022-09-16T00:00:00',
#    'issue': '捷傑有限公司',
#    'produce': 'Shochiku Co.,Ltd',
#    'theaterCount': 11,
#    'tickets': 178,
#    'ticketChangeRate': -0.9295607439651761,
#    'amounts': 43980.0,
#    'totalTickets': 2705,
#    'totalAmounts': 636686.0},
#   {'country': '美國',
#    'name': '蜘蛛人：無家日 戲院加長版',
#    'releaseDate': '2021-12-15T00:00:00',
#    'issue': '美商台灣索尼影業發行股份有限公司台灣分公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 1,
#    'tickets': 9,
#    'ticketChangeRate': -0.9982032341784788,
#    'amounts': 2910.0,
#    'totalTickets': 5018,
#    'totalAmounts': 1439492.0},
#   {'country': '日本',
#    'name': '河畔小日子',
#    'releaseDate': '2022-10-03T00:00:00',
#    'issue': '政駒實業有限公司',
#    'produce': 'KADOKAWA CORPORATION',
#    'theaterCount': 21,
#    'tickets': 1783,
#    'ticketChangeRate': 1.0,
#    'amounts': 399753.0,
#    'totalTickets': 1783,
#    'totalAmounts': 399753.0},
#   {'country': '日本',
#    'name': '劇場版 超時空要塞F~戀離飛翼~',
#    'releaseDate': '2022-10-21T00:00:00',
# ...
#    'amounts': 416826.0,
#    'totalTickets': 1788,
#    'totalAmounts': 416826.0},
#   {'country': '日本',
#    'name': '幽靜的山荷葉',
#    'releaseDate': '2022-11-11T00:00:00',
#    'issue': '希望行銷娛樂有限公司',
#    'produce': 'Nagoya Broadcasting Network Co., Ltd.',
#    'theaterCount': 10,
#    'tickets': 491,
#    'ticketChangeRate': 1.0,
#    'amounts': 102390.0,
#    'totalTickets': 491,
#    'totalAmounts': 102390.0},
#   {'country': '韓國',
#    'name': '笑子當老大',
#    'releaseDate': '2022-10-28T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': 'Atrium Productions Kft.',
#    'theaterCount': 40,
#    'tickets': 1476,
#    'ticketChangeRate': 1.0,
#    'amounts': 333872.0,
#    'totalTickets': 1476,
#    'totalAmounts': 333872.0},
#   {'country': '澳門',
#    'name': '海鷗來過的房間',
#    'releaseDate': '2022-11-11T00:00:00',
#    'issue': '海鵬影業有限公司',
#    'produce': '地地影像工房有限公司',
#    'theaterCount': 13,
#    'tickets': 789,
#    'ticketChangeRate': 1.0,
#    'amounts': 167510.0,
#    'totalTickets': 789,
#    'totalAmounts': 167510.0},
#   {'country': '瑞典',
#    'name': '星夢性快感',
#    'releaseDate': '2022-11-11T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'VERSATILE',
#    'theaterCount': 17,
#    'tickets': 358,
#    'ticketChangeRate': 1.0,
#    'amounts': 81848.0,
#    'totalTickets': 358,
#    'totalAmounts': 81848.0},
#   {'country': '日本',
#    'name': '天空之城(日文版)',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '香港商甲上娛樂有限公司台灣分公司',
#    'produce': 'Studio Ghibli Inc.',
#    'theaterCount': 70,
#    'tickets': 33550,
#    'ticketChangeRate': 1.0,
#    'amounts': 8388111.0,
#    'totalTickets': 33550,
#    'totalAmounts': 8388111.0},
#   {'country': '美國',
#    'name': '鬼禱',
#    'releaseDate': '2022-10-28T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'FLAMING DEVILS, LLC',
#    'theaterCount': 65,
#    'tickets': 34070,
#    'ticketChangeRate': 1.0,
#    'amounts': 8210829.0,
#    'totalTickets': 34070,
#    'totalAmounts': 8210829.0},
#   {'country': '英國',
#    'name': '大製片家',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '佳映娛樂國際股份有限公司',
#    'produce': 'VISIT FILMS, LLC',
#    'theaterCount': 11,
#    'tickets': 133,
#    'ticketChangeRate': 1.0,
#    'amounts': 28081.0,
#    'totalTickets': 133,
#    'totalAmounts': 28081.0},
#   {'country': '日本',
#    'name': '通往異世界的便利店',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '天馬行空數位有限公司',
#    'produce': 'Free Stone Productions Co., Ltd.,',
#    'theaterCount': 11,
#    'tickets': 284,
#    'ticketChangeRate': 1.0,
#    'amounts': 61243.0,
#    'totalTickets': 284,
#    'totalAmounts': 61243.0},
#   {'country': '西班牙',
#    'name': '遺屍物',
#    'releaseDate': '2022-11-04T00:00:00',
#    'issue': '原創娛樂股份有限公司',
#    'produce': 'Castelao Pictures, S.L.U.',
#    'theaterCount': 15,
#    'tickets': 696,
#    'ticketChangeRate': 1.0,
#    'amounts': 167306.0,
#    'totalTickets': 696,
#    'totalAmounts': 167306.0},
#   {'country': '喬治亞',
#    'name': '喬治亞天空下 ',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '好威映象有限公司',
#    'produce': 'CERCAMON MFZE ',
#    'theaterCount': 10,
#    'tickets': 414,
#    'ticketChangeRate': 1.0,
#    'amounts': 88852.0,
#    'totalTickets': 414,
#    'totalAmounts': 88852.0},
#   {'country': '法國',
#    'name': '索蘭琪的少女心事',
#    'releaseDate': '2022-11-04T00:00:00',
#    'issue': '東昊影業有限公司',
#    'produce': 'ＭＫ2 Films',
#    'theaterCount': 10,
#    'tickets': 149,
#    'ticketChangeRate': 1.0,
#    'amounts': 30304.0,
#    'totalTickets': 149,
#    'totalAmounts': 30304.0},
#   {'country': '日本',
#    'name': '錯位的青春',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 21,
#    'tickets': 451,
#    'ticketChangeRate': 1.0,
#    'amounts': 106542.0,
#    'totalTickets': 451,
#    'totalAmounts': 106542.0},
#   {'country': '美國',
#    'name': '骨肉的總和',
#    'releaseDate': '2022-11-24T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 50,
#    'tickets': 15117,
#    'ticketChangeRate': 1.0,
#    'amounts': 3829612.0,
#    'totalTickets': 15117,
#    'totalAmounts': 3829612.0},
#   {'country': '韓國',
#    'name': '局中局',
#    'releaseDate': '2022-11-04T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 66,
#    'tickets': 25322,
#    'ticketChangeRate': 1.0,
#    'amounts': 6045877.0,
#    'totalTickets': 25322,
#    'totalAmounts': 6045877.0},
#   {'country': '中國大陸',
#    'name': '四海',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '恆星多媒體股份有限公司',
#    'produce': '上海亭東影業有限公司,阿里巴巴影業（北京）有限公司,新疆博納潤澤文化傳媒有限公司,霍爾果斯聯瑞影業有限公司,中國電影股份有限公司,天津貓眼微影文化傳媒有限公司,浙江橫店影業有限公司,上海電影（集團）有限公司,果麥文化傳媒股份有限公司,海口那可是家大影視文化有限公司,融創未來文化娛樂（北京）有限公司,北京國影縱橫電影發行有限公司,廈門人馬文化傳媒有限公司,北京耀影電影發行有限公司,霍爾果斯有忻影業有限公司,北京微夢創科網絡技術有限公司,抖音文化（廈門）有限公司',
#    'theaterCount': 1,
#    'tickets': 254,
#    'ticketChangeRate': 1.0,
#    'amounts': 56940.0,
#    'totalTickets': 254,
#    'totalAmounts': 56940.0},
#   {'country': '美國',
#    'name': '貓爸爸們',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '捷傑有限公司',
#    'produce': 'MOTION PICTURE EXCHANGE,LLC',
#    'theaterCount': 5,
#    'tickets': 244,
#    'ticketChangeRate': 1.0,
#    'amounts': 52980.0,
#    'totalTickets': 244,
#    'totalAmounts': 52980.0},
#   {'country': '日本',
#    'name': '天才狂歡派對：首部曲',
#    'releaseDate': '2022-11-01T00:00:00',
#    'issue': '光年映畫有限公司',
#    'produce': ' Beyond C. Co., Ltd.',
#    'theaterCount': 21,
#    'tickets': 2227,
#    'ticketChangeRate': 1.0,
#    'amounts': 567348.0,
#    'totalTickets': 2227,
#    'totalAmounts': 567348.0},
#   {'country': '日本',
#    'name': '天才狂歡派對：最終章',
#    'releaseDate': '2022-11-28T00:00:00',
#    'issue': '光年映畫有限公司',
#    'produce': ' Beyond C. Co., Ltd.',
#    'theaterCount': 21,
#    'tickets': 1218,
#    'ticketChangeRate': 1.0,
#    'amounts': 310213.0,
#    'totalTickets': 1218,
#    'totalAmounts': 310213.0},
#   {'country': '日本',
#    'name': '即使，這份戀情今晚會從世上消失',
#    'releaseDate': '2022-11-11T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'TOHO CO., LTD.',
#    'theaterCount': 54,
#    'tickets': 26712,
#    'ticketChangeRate': 1.0,
#    'amounts': 6690691.0,
#    'totalTickets': 26712,
#    'totalAmounts': 6690691.0},
#   {'country': '美國',
#    'name': '絕命線阱',
#    'releaseDate': '2022-11-04T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': 'GEM ENTERTAINMENT KFT.',
#    'theaterCount': 46,
#    'tickets': 3636,
#    'ticketChangeRate': 1.0,
#    'amounts': 832606.0,
#    'totalTickets': 3636,
#    'totalAmounts': 832606.0},
#   {'country': '韓國',
#    'name': '厄憶追凶',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 60,
#    'tickets': 12366,
#    'ticketChangeRate': 1.0,
#    'amounts': 2858720.0,
#    'totalTickets': 12366,
#    'totalAmounts': 2858720.0},
#   {'country': '日本',
#    'name': '葬禮',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '台北双喜電影發行股份有限公司',
#    'produce': 'Itami Productions Co., Ltd.',
#    'theaterCount': 14,
#    'tickets': 1786,
#    'ticketChangeRate': 1.0,
#    'amounts': 393485.0,
#    'totalTickets': 1786,
#    'totalAmounts': 393485.0},
#   {'country': '日本',
#    'name': '蒲公英',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '台北双喜電影發行股份有限公司',
#    'produce': 'Itami Productions Co., Ltd.',
#    'theaterCount': 14,
#    'tickets': 1623,
#    'ticketChangeRate': 1.0,
#    'amounts': 367028.0,
#    'totalTickets': 1623,
#    'totalAmounts': 367028.0},
#   {'country': '美國',
#    'name': '黑豹 2：瓦干達萬歲',
#    'releaseDate': '2022-11-09T00:00:00',
#    'issue': '台灣華特迪士尼股份有限公司',
#    'produce': 'BUENA VISTA INTERNATIONAL, INC.',
#    'theaterCount': 97,
#    'tickets': 902656,
#    'ticketChangeRate': 1.0,
#    'amounts': 243951721.0,
#    'totalTickets': 902656,
#    'totalAmounts': 243951721.0},
#   {'country': '美國',
#    'name': '她有話要說',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 84,
#    'tickets': 6003,
#    'ticketChangeRate': 1.0,
#    'amounts': 1411915.0,
#    'totalTickets': 6003,
#    'totalAmounts': 1411915.0},
#   {'country': '泰國',
#    'name': '愛情需要編劇',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '采昌國際多媒體股份有限公司',
#    'produce': 'M PICTURES COMPANY LIMITED',
#    'theaterCount': 36,
#    'tickets': 2203,
#    'ticketChangeRate': 1.0,
#    'amounts': 495989.0,
#    'totalTickets': 2203,
#    'totalAmounts': 495989.0},
#   {'country': '日本',
#    'name': '性徒',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '中影股份有限公司',
#    'produce': 'The Klockworx Co. Ltd.',
#    'theaterCount': 10,
#    'tickets': 937,
#    'ticketChangeRate': 1.0,
#    'amounts': 208815.0,
#    'totalTickets': 937,
#    'totalAmounts': 208815.0},
#   {'country': '日本',
#    'name': '修羅天魔~骷髏城之七人．極 （新感線舞台劇）',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '威秀影城股份有限公司',
#    'produce': 'Village INC.',
#    'theaterCount': 6,
#    'tickets': 153,
#    'ticketChangeRate': 1.0,
#    'amounts': 82680.0,
#    'totalTickets': 153,
#    'totalAmounts': 82680.0},
#   {'country': '日本',
#    'name': '劇場版 歌之☆王子殿下♪ 真愛ST☆RISH TOURS',
#    'releaseDate': '2022-11-18T00:00:00',
#    'issue': '曼迪傳播有限公司',
#    'produce': 'KING RECORD CO., LTD.',
#    'theaterCount': 15,
#    'tickets': 9068,
#    'ticketChangeRate': 1.0,
#    'amounts': 2277554.0,
#    'totalTickets': 9068,
#    'totalAmounts': 2277554.0},
#   {'country': '西班牙',
#    'name': '放牛班足球隊',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '仲業股份有限公司',
#    'produce': 'FILM FACTORY ENTERTAINMENT, S.L.',
#    'theaterCount': 15,
#    'tickets': 1018,
#    'ticketChangeRate': 1.0,
#    'amounts': 226197.0,
#    'totalTickets': 1018,
#    'totalAmounts': 226197.0},
#   {'country': '美國',
#    'name': '俠探特攻：全面追緝',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 35,
#    'tickets': 2945,
#    'ticketChangeRate': 1.0,
#    'amounts': 705763.0,
#    'totalTickets': 2945,
#    'totalAmounts': 705763.0},
#   {'country': '美國',
#    'name': '奇異冒險 (英文版)',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '台灣華特迪士尼股份有限公司',
#    'produce': 'BUENA VISTA INTERNATIONAL, INC.',
#    'theaterCount': 79,
#    'tickets': 23789,
#    'ticketChangeRate': 1.0,
#    'amounts': 5690344.0,
#    'totalTickets': 23789,
#    'totalAmounts': 5690344.0},
#   {'country': '韓國',
#    'name': '音爆浩劫',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 69,
#    'tickets': 70820,
#    'ticketChangeRate': 1.0,
#    'amounts': 16646790.0,
#    'totalTickets': 70820,
#    'totalAmounts': 16646790.0},
#   {'country': '日本',
#    'name': '通往夏天的隧道，再見的出口',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 64,
#    'tickets': 35775,
#    'ticketChangeRate': 1.0,
#    'amounts': 8860912.0,
#    'totalTickets': 35775,
#    'totalAmounts': 8860912.0},
#   {'country': '美國',
#    'name': '暴戾夜',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '美商美國環球影片股份有限公司台灣分公司',
#    'produce': 'UNIVERSAL INTERNATIONAL FILMS LLC',
#    'theaterCount': 90,
#    'tickets': 25039,
#    'ticketChangeRate': 1.0,
#    'amounts': 6061213.0,
#    'totalTickets': 25039,
#    'totalAmounts': 6061213.0},
#   {'country': '美國',
#    'name': '決戰38度線',
#    'releaseDate': '2022-11-30T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': 'STX PRODUCTIONS, LLC',
#    'theaterCount': 74,
#    'tickets': 32388,
#    'ticketChangeRate': 1.0,
#    'amounts': 7789510.0,
#    'totalTickets': 32388,
#    'totalAmounts': 7789510.0},
#   {'country': '日本',
#    'name': '戀上笨拙的你',
#    'releaseDate': '2022-11-25T00:00:00',
#    'issue': '英屬維京群島商映畫聯合有限公司台灣分公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 3,
#    'tickets': 69,
#    'ticketChangeRate': 1.0,
#    'amounts': 15630.0,
#    'totalTickets': 69,
#    'totalAmounts': 15630.0},
#   {'country': '日本',
#    'name': '還有愛的日子',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '海鵬影業有限公司',
#    'produce': 'MK2 FILMS',
#    'theaterCount': 14,
#    'tickets': 1076,
#    'ticketChangeRate': 1.0,
#    'amounts': 230918.0,
#    'totalTickets': 1076,
#    'totalAmounts': 230918.0},
#   {'country': '印度',
#    'name': '梵天神器：滅世開端',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '原創娛樂股份有限公司',
#    'produce': 'STAR INDIA PRIVATE LIMITED',
#    'theaterCount': 36,
#    'tickets': 3797,
#    'ticketChangeRate': 1.0,
#    'amounts': 1053279.0,
#    'totalTickets': 3797,
#    'totalAmounts': 1053279.0},
#   {'country': '韓國',
#    'name': '王者製造',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '華映娛樂股份有限公司',
#    'produce': 'M LINE DISTRIBUTION',
#    'theaterCount': 32,
#    'tickets': 2083,
#    'ticketChangeRate': 1.0,
#    'amounts': 474568.0,
#    'totalTickets': 2083,
#    'totalAmounts': 474568.0},
#   {'country': '韓國',
#    'name': 'NCT DREAM THE MOVIE : In A DREAM',
#    'releaseDate': '2022-11-30T00:00:00',
#    'issue': '威秀影城股份有限公司',
#    'produce': 'Trafalgar Releasing Ltd.',
#    'theaterCount': 10,
#    'tickets': 4848,
#    'ticketChangeRate': 1.0,
#    'amounts': 2304050.0,
#    'totalTickets': 4848,
#    'totalAmounts': 2304050.0},
#   {'country': '韓國',
#    'name': '整形帝王',
#    'releaseDate': '2022-12-02T00:00:00',
#    'issue': '車庫娛樂股份有限公司',
#    'produce': 'RELAY MOTION KFT.',
#    'theaterCount': 60,
#    'tickets': 9377,
#    'ticketChangeRate': 1.0,
#    'amounts': 2148990.0,
#    'totalTickets': 9377,
#    'totalAmounts': 2148990.0},
#   {'country': '日本',
#    'name': '魔幻時刻',
#    'releaseDate': '2008-12-31T00:00:00',
#    'issue': '傳影互動股份有限公司',
#    'produce': 'PONY CANYON INC.',
#    'theaterCount': 1,
#    'tickets': 228,
#    'ticketChangeRate': 1.0,
#    'amounts': 57000.0,
#    'totalTickets': 228,
#    'totalAmounts': 57000.0},
#   {'country': '法國',
#    'name': '玩命光頭',
#    'releaseDate': '2016-11-04T00:00:00',
#    'issue': '原創娛樂股份有限公司',
#    'produce': 'OTHER ANGLE PICTURES',
#    'theaterCount': 21,
#    'tickets': 458,
#    'ticketChangeRate': 1.0,
#    'amounts': 113191.0,
#    'totalTickets': 1738,
#    'totalAmounts': 328516.0},
#   {'country': '中華民國',
#    'name': '風中家族',
#    'releaseDate': '2015-07-24T00:00:00',
#    'issue': '威視股份有限公司',
#    'produce': '興揚電影有限公司,中環國際娛樂事業股份有限公司,威視股份有限公司,阿榮影業股份有限公司,財團法人高雄市文化基金會',
#    'theaterCount': 1,
#    'tickets': 30,
#    'ticketChangeRate': 1.0,
#    'amounts': 3020.0,
#    'totalTickets': 30,
#    'totalAmounts': 3020.0},
#   {'country': '英國',
#    'name': '八月三十一日，我在奧斯陸',
#    'releaseDate': '2013-05-31T00:00:00',
#    'issue': '美昇國際影業股份有限公司',
#    'produce': '(德國)THE MATCH FACTORY GMBH',
#    'theaterCount': 1,
#    'tickets': 34,
#    'ticketChangeRate': -0.962800875273523,
#    'amounts': 7060.0,
#    'totalTickets': 3319,
#    'totalAmounts': 759417.0},
#   {'country': '中華民國',
#    'name': '春光乍洩',
#    'releaseDate': '1997-06-07T00:00:00',
#    'issue': '英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司',
#    'produce': '春光電影發行有限公司',
#    'theaterCount': 1,
#    'tickets': 145,
#    'ticketChangeRate': 35.25,
#    'amounts': 36250.0,
#    'totalTickets': 12554,
#    'totalAmounts': 3162382.0},
#   {'country': '英國',
#    'name': '發條橘子',
#    'releaseDate': '2017-12-29T00:00:00',
#    'issue': '聯影企業股份有限公司',
#    'produce': '(英國)PARK CIRCUS LIMITED',
#    'theaterCount': 1,
#    'tickets': 5,
#    'ticketChangeRate': -0.9986033519553073,
#    'amounts': 1140.0,
#    'totalTickets': 9340,
#    'totalAmounts': 2196954.0},
#   {'country': '美國',
#    'name': '以你的名字呼喚我',
#    'releaseDate': '2018-01-12T00:00:00',
#    'issue': '博偉電影股份有限公司',
#    'produce': 'SONY PICTURES RELEASING INTERNATIONAL CORPORATION.',
#    'theaterCount': 21,
#    'tickets': 2581,
#    'ticketChangeRate': 1.0,
#    'amounts': 674764.0,
#    'totalTickets': 33069,
#    'totalAmounts': 7763159.0},
#   {'country': '美國',
#    'name': '2001太空漫遊',
#    'releaseDate': '2018-06-04T00:00:00',
#    'issue': '美商華納兄弟（遠東）股份有限公司台灣分公司',
#    'produce': 'WARNER BROS. PICTURES INTERNATIONAL.',
#    'theaterCount': 20,
#    'tickets': 1003,
#    'ticketChangeRate': -0.6765559496936472,
#    'amounts': 238594.0,
#    'totalTickets': 8425,
#    'totalAmounts': 2117645.0},
#   {'country': '法國',
#    'name': '衡量一個人',
#    'releaseDate': '2015-11-20T00:00:00',
#    'issue': '海鵬影業',
#    'produce': 'MK2',
#    'theaterCount': 1,
#    'tickets': 74,
#    'ticketChangeRate': 1.0,
#    'amounts': 17760.0,
#    'totalTickets': 74,
#    'totalAmounts': 17760.0},
#   {'country': '日本',
#    'name': '龍貓',
#    'releaseDate': '2021-01-29T00:00:00',
#    'issue': '台灣華特迪士尼股份有限公司',
#    'produce': 'STUDIO GHIBLI INC.',
#    'theaterCount': 1,
#    'tickets': 131,
#    'ticketChangeRate': 1.0,
#    'amounts': 28820.0,
#    'totalTickets': 52510,
#    'totalAmounts': 12417823.0}]}
